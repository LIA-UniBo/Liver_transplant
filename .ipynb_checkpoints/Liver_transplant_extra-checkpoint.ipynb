# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import seaborn as sns
from scipy.stats import pearsonr, spearmanr

from matplotlib import pyplot as plt
from matplotlib import ticker

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import accuracy_score, plot_confusion_matrix, ConfusionMatrixDisplay, confusion_matrix, make_scorer, roc_curve, auc

from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import SimpleImputer, IterativeImputer

from sklearn.ensemble import ExtraTreesClassifier, RandomForestClassifier
from sklearn.tree import plot_tree

from sklearn.dummy import DummyClassifier

from boruta import BorutaPy

from utils import plot_pie, plot_hist, plot_barh, plot_barv_date
from utils import get_freq_nan_std, get_freq_nan_tipo_combinato, get_freq_nan_data_decesso, get_freq_nan_tx
from utils import get_min_value, get_max_value
from utils import get_cost, get_cost_tf

import tensorflow as tf
from utils import NeuralNetwork

import warnings
warnings.filterwarnings('ignore')

seed = 42
show_plot = True
# Out:
#   Input In [1]
#     from sklearn.metrics import accuracy_score, plot_confusion_matrix, ConfusionMatrixDisplay, confusion_matrix make_scorer, roc_curve, auc
#                                                                                                                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# <h1><span style="color:#191996">Artificial Intelligence in Industry</span></h1>
#
# ### 5-year survival of liver transplant patients
#
# <br/><br/>
#
# #### _Presented by Giacomo Pinardi_

# %% [markdown]
# <h2><span style="color:#191996">Table of contents</span></h2>
#
# 1. Problem description
# 2. Data loading
# 3. Small data description
# 4. Missing values
# 5. Creation of X and y
# 6. Training

# %% [markdown]
# <h2><span style="color:#191996">1. Problem description</span></h2>
#
# Given a dataset containing information related to patients that undergo liver transplant, determine their survival after 5 years.
#
# Challanges:
#  - Missing Values
#  - Filtering is required
#  - Unbalanced classes
#  - Accuracy is not a useful metric

# %% [markdown]
# <h2><span style="color:#191996">2. Data loading</span></h2>
#
# Let's create a dataframe from the Excel file:

# %%
df = pd.read_excel('../data.xlsx', engine='openpyxl')
df.shape
# Out:
# (2311, 146)

# %%
df.columns
# Out:
# Index(['ctx', 'codice_dm', 'lista_id', 'pers_sesso',
#        'pers_eta_ingresso_in_lista', 'diagnosi', 'diagnosi_specifica', 'eltr',
#        'lista_ingresso_data', 'tot_tx_organo',
#        ...
#        'donatore_HBeAg', 'donatore_HBeAb', 'donatore_antiCoreTot',
#        'donatore_hbv_dna', 'donatore_hcv_rna', 'donatore_steatosiMacro',
#        'donatore_biopsiaEpatica', 'donatore_biopsiaRenale',
#        'donatore_livelloRischioPreLT', 'donatore_variazioneLivello'],
#       dtype='object', length=146)

# %% [markdown]
# Remove unnecessary or not useful columns:

# %%
to_remove = ['ctx', 'codice_dm', 'lista_id', 'diagnosi_specifica', 'eltr', 'ric_eccezione_MELD_PELD', 'Na', 'chirurgia_addom_note', 'trombosi_portale_note', 'categoria_HCC', 'HCC_esordio', 'HCC_noduli', 'HCC_downstaging', 'HCC_diam_max', 'HCC_diam_totale', 'HCC_stadio_TNM', 'HCC_resezione', 'tx_effettivo_data', 'scheda48h_tx_effettivo_combinato', 'scheda48h_tipo_tx_effettivo_combinato', 'fega_note', 'data_UNOS', 'ISO2_tipo_super_urgenza', 'ISO2_Ecc. MELD', 'ISO2_valid_score', 'ISO2_valid_increment', 'ISO2_valid_giorni', 'ISO2_valid_mesi', 'ISO2_valid_anzianita', 'ISO2_allocazione', 'codice_sit_donazione', 'donazione_ospedale', 'donazione_sede', 'trap_don_decesso_id', 'donatore_decesso_note', 'donatore_note', 'donatore_giorni_ricovero', 'donatore_cardiopatie_desc', 'donatore_ipertensione_desc', 'donatore_diabete_desc', 'donatore_diabete_insulinodipendente_desc', 'donatore_dislipidemie_desc', 'donatore_bassaportata1_data', 'donatore_bassaportata1_ora', 'donatore_bassaportata1_durata', 'donatore_bassaportata1_PAmax', 'donatore_bassaportata1_PAmin', 'donatore_bassaportata1_trattamento', 'donatore_bassaportata2_data', 'donatore_bassaportata2_ora', 'donatore_bassaportata2_durata', 'donatore_bassaportata2_PAmax', 'donatore_bassaportata2_PAmin', 'donatore_bassaportata2_trattamento', 'donatore_bassaportata3_data', 'donatore_bassaportata3_ora', 'donatore_bassaportata3_durata', 'donatore_bassaportata3_PAmax', 'donatore_bassaportata3_PAmin', 'donatore_bassaportata3_trattamento', 'donatore_HBeAg', 'donatore_biopsiaEpatica', 'donatore_biopsiaRenale', 'donatore_variazioneLivello']

df = df.drop(to_remove, axis=1)

print(f'Removed {len(to_remove)} columns from the dataframe')
# Out:
# Removed 64 columns from the dataframe

# %%
df.shape
# Out:
# (2311, 82)

# %% [markdown]
# <h2><span style="color:#191996">3. Small data description</span></h2>

# %% [markdown]
# The dataframe file contains different patient "types" (someone received a transplant, others left since their condition improved, ...).

# %%
df[['pers_sesso', 'MELD_base', 'diagnosi', 'causa_uscita', 'data_trapianto', 'donatore_eta']]
# Out:
#      pers_sesso  MELD_base                                           diagnosi  \
# 0             M        8.0                                   Altra epatopatia
# 1             M       10.0                       Cirrosi postnecrotica da HCV
# 2             M       13.0                Cirrosi criptogenetica o idiopatica
# 3             M       14.0                 Cirrosi di Laennec (post-alcolica)
# 4             M       16.0                       Cirrosi postnecrotica da HCV
# ...         ...        ...                                                ...
# 2306          M       12.0                 Epatocarcinoma associato a cirrosi
# 2307          M       18.0  Localizzazione epatiche di neoplasie maligne o...
# 2308          M        9.0                 Epatocarcinoma associato a cirrosi
# 2309          F       25.0                          Cirrosi biliare primitiva
# 2310          M       19.0                       Altra epatopatia colestatica
#
#                      causa_uscita data_trapianto  donatore_eta
# 0     TX nel centro di iscrizione     2004-10-22          19.0
# 1         Non idoneo clinicamente            NaT           NaN
# 2        Uscito per miglioramento            NaT           NaN
# 3      Deceduto iscritto in lista            NaT           NaN
# 4      Deceduto iscritto in lista            NaT           NaN
# ...                           ...            ...           ...
# 2306  TX nel centro di iscrizione     2020-12-08          53.0
# 2307  TX nel centro di iscrizione     2020-10-23          46.0
# 2308  TX nel centro di iscrizione     2020-11-07          82.0
# 2309  TX nel centro di iscrizione     2020-12-29          70.0
# 2310  TX nel centro di iscrizione     2020-12-05          13.0
#
# [2311 rows x 6 columns]

# %%
df.head()
# Out:
#   pers_sesso  pers_eta_ingresso_in_lista                             diagnosi  \
# 0          M                          54                     Altra epatopatia
# 1          M                          64         Cirrosi postnecrotica da HCV
# 2          M                          56  Cirrosi criptogenetica o idiopatica
# 3          M                          51   Cirrosi di Laennec (post-alcolica)
# 4          M                          43         Cirrosi postnecrotica da HCV
#
#   lista_ingresso_data  tot_tx_organo  tx_fegato_corrente iscriz_tx_comb  \
# 0          2004-03-10            0.0                 1.0             SI
# 1          2003-12-02            NaN                 NaN             NO
# 2          2002-07-18            0.0                 1.0             NO
# 3          2003-06-26            NaN                 NaN             NO
# 4          2004-01-08            NaN                 NaN             NO
#
#    tipo_combinato ric_HBsAg ric_DELTA  ... donatore_arresto_cardiaco  \
# 0  cuore - fegato        NO        NO  ...                       NaN
# 1             NaN        NO       NaN  ...                       NaN
# 2             NaN        NO        NO  ...                       NaN
# 3             NaN        NO       NaN  ...                       NaN
# 4             NaN        NO       NaN  ...                       NaN
#
#   donatore_hcv donatore_HBsAg  donatore_HBsAb  donatore_HBeAb  \
# 0          NaN            NaN             NaN             NaN
# 1          NaN            NaN             NaN             NaN
# 2          NaN            NaN             NaN             NaN
# 3          NaN            NaN             NaN             NaN
# 4          NaN            NaN             NaN             NaN
#
#    donatore_antiCoreTot  donatore_hbv_dna  donatore_hcv_rna  \
# 0                   NaN               NaN               NaN
# 1                   NaN               NaN               NaN
# 2                   NaN               NaN               NaN
# 3                   NaN               NaN               NaN
# 4                   NaN               NaN               NaN
#
#   donatore_steatosiMacro donatore_livelloRischioPreLT
# 0                    NaN                          NaN
# 1                    NaN                          NaN
# 2                    NaN                          NaN
# 3                    NaN                          NaN
# 4                    NaN                          NaN
#
# [5 rows x 82 columns]

# %%
df.describe()
# Out:
#        pers_eta_ingresso_in_lista  tot_tx_organo  tx_fegato_corrente  \
# count                 2311.000000    1847.000000         1852.000000
# mean                    52.361748       0.102328            1.072354
# std                     10.332137       0.338613            0.281142
# min                     11.000000       0.000000            1.000000
# 25%                     47.000000       0.000000            1.000000
# 50%                     54.000000       0.000000            1.000000
# 75%                     60.000000       0.000000            1.000000
# max                     73.000000       3.000000            4.000000
#
#               Peso      Altezza          BMI  MELD_in_ingresso  \
# count  2261.000000  2260.000000  2260.000000        591.000000
# mean     73.536444   169.861062    25.385093         17.065990
# std      15.177244     9.086432     4.392849          8.810474
# min      23.000000   127.000000    11.400000          6.000000
# 25%      63.000000   164.000000    22.477500         10.000000
# 50%      73.000000   170.000000    25.060000         15.000000
# 75%      83.000000   176.000000    27.920000         22.000000
# max     133.000000   205.000000    46.290000         56.000000
#
#        MELD_in_uscita    MELD_base     MELD_na  ...  donatore_bilirubinaTot1  \
# count      591.000000  2259.000000  163.000000  ...               780.000000
# mean        18.367174    19.130146   21.306748  ...                 0.761744
# std          9.634448     9.211320    9.453154  ...                 0.658497
# min          6.000000     6.000000    6.000000  ...                 0.100000
# 25%         10.500000    12.000000   14.000000  ...                 0.410000
# 50%         16.000000    17.000000   21.000000  ...                 0.600000
# 75%         25.000000    26.000000   28.500000  ...                 0.910000
# max         51.000000    51.000000   48.000000  ...                10.900000
#
#        donatore_bilirubinaTot2  donatore_bilirubinaTot3  donatore_fosfatasi1  \
# count               735.000000                528.00000           308.000000
# mean                  0.853116                  1.02608            99.042208
# std                   0.772087                  4.06535            63.488706
# min                   0.060000                  0.10000            13.000000
# 25%                   0.440000                  0.42000            55.000000
# 50%                   0.680000                  0.63000            77.000000
# 75%                   1.000000                  0.99250           125.250000
# max                   8.900000                 92.00000           374.000000
#
#        donatore_fosfatasi2  donatore_fosfatasi3  donatore_gammaGT1  \
# count           536.000000           357.000000         399.000000
# mean            100.472015           113.743249          45.858822
# std             123.688006            95.895910          62.604162
# min               0.400000             3.340000           0.670000
# 25%              52.000000            60.000000          14.000000
# 50%              71.000000            88.000000          24.000000
# 75%             110.250000           138.000000          48.000000
# max            1959.000000           914.000000         496.000000
#
#        donatore_gammaGT2  donatore_gammaGT3  donatore_steatosiMacro
# count         593.000000         391.000000              767.000000
# mean           46.215852          66.798210                6.091134
# std            64.369294          95.280876                7.951754
# min             0.000000           0.100000                0.000000
# 25%            15.000000          17.000000                0.000000
# 50%            24.000000          33.000000                5.000000
# 75%            46.000000          78.000000               10.000000
# max           576.000000        1013.000000               50.000000
#
# [8 rows x 35 columns]

# %% [markdown]
# <h2><span style="color:#191996">4. Missing values</span></h2>

# %% [markdown]
# ### Rough estimation of missing values
# Every `NaN` value is considered a missing value.

# %%
missing_percent = {}
for column in df.columns:
    missing_percent[column] = df[column].isna().sum() / len(df)
for column in sorted(missing_percent, key=missing_percent.get, reverse=True):
    print('{}: {:.3f}'.format(column, missing_percent[column]))
# Out:
# tipo_combinato: 0.944
# donatore_HBeAb: 0.935
# MELD_na: 0.929
# donatore_fosfatasi1: 0.867
# MELD_HCC: 0.864
# donatore_fosfatasi3: 0.846
# donatore_gammaGT3: 0.831
# donatore_gammaGT1: 0.827
# donatore_AST3: 0.776
# donatore_bilirubinaTot3: 0.772
# donatore_fosfatasi2: 0.768
# donatore_ALT3: 0.756
# MELD_in_ingresso: 0.744
# MELD_in_uscita: 0.744
# donatore_sodio3: 0.744
# donatore_gammaGT2: 0.743
# AFP: 0.734
# ultimo_stato_tx: 0.694
# data_ultimo_agg_followup: 0.692
# donatore_AST2: 0.691
# donatore_AST1: 0.688
# donatore_bilirubinaTot2: 0.682
# rigetto: 0.669
# donatore_steatosiMacro: 0.668
# data_decesso: 0.667
# donatore_ALT2: 0.666
# donatore_bilirubinaTot1: 0.662
# ric_ripresa_funzionale: 0.642
# donatore_sodio2: 0.630
# donatore_hbv_dna: 0.628
# donatore_diabete_insulinodipendente: 0.626
# donatore_hcv_rna: 0.625
# donatore_ALT1: 0.623
# donatore_HBsAb: 0.613
# donatore_sodio1: 0.575
# TIPS: 0.527
# dialisi_ultimi_15gg: 0.505
# ric_DELTA: 0.505
# donatore_livelloRischioPreLT: 0.495
# donatore_dislipidemie: 0.494
# donatore_arresto_cardiaco: 0.484
# donatore_cardiopatia: 0.482
# donatore_ipertensione: 0.479
# donatore_diabete: 0.478
# donatore_altezza: 0.468
# donatore_BMI: 0.468
# donatore_hcv: 0.468
# donatore_antiCoreTot: 0.468
# donatore_peso: 0.467
# donatore_HBsAg: 0.467
# organo_trapiantato: 0.464
# ric_ospedalizzazione_al_tx: 0.463
# ric_HCV_RNA: 0.415
# donatore_caus_decesso: 0.389
# donatore_sesso: 0.383
# donatore_eta: 0.381
# ischemia_fredda: 0.380
# tipo_donazione: 0.378
# data_trapianto: 0.376
# CHILD: 0.235
# ric_diabete: 0.218
# tot_tx_organo: 0.201
# tx_fegato_corrente: 0.199
# UNOS: 0.062
# diagnosi: 0.049
# ric_HIV: 0.040
# chirurgia_addom: 0.038
# trombosi_portale: 0.037
# ric_HCV: 0.036
# ric_HBsAg: 0.035
# HCC: 0.029
# MELD_base: 0.023
# Altezza: 0.022
# BMI: 0.022
# Peso: 0.022
# causa_uscita: 0.003
# pers_sesso: 0.000
# pers_eta_ingresso_in_lista: 0.000
# lista_ingresso_data: 0.000
# iscriz_tx_comb: 0.000
# lista_uscita_data: 0.000
# ISO2_super_urgenza: 0.000

# %%
# Overall dataset
print('{:.3f}'.format(df.isna().sum().sum() / (len(df) * len(df.columns))))
# Out:
# 0.460

# %% [markdown]
# #### Strategies to deal with missing values:
# - Talk to the expert: is there a **default value** that can be used?
#
#
# - Statistical approach, using **missing values imputation**:
#     - Univariate feature imputation with `SimpleImputer` (mean, most frequent, ...);
#     - Multivariate feature imputation with `IterativeImputer` (model each feature with missing values as a function of other features).
#
#
# - Remove rows/columns with too many missing values. Should be avoided when the above strategies are possible.

# %% [markdown]
# ### Precise estimation of missing values
# A `NaN` value is considered a missing value depending on the context. If the patient did not receive a transplant then the values related to the nonexistent donor are **not** missing values.

# %%
def get_freq_nan_tx (df: pd.DataFrame, column_name: str):
    tx = ['TX nel centro di iscrizione',
          'Trapiantato da VIVENTE in questo Centro',
          'Trapianto in altra sede non specificata',
          'Trapianto AIRT fuori Regione']
    
    return ((df['causa_uscita'].isin(tx)) & (pd.isna(df[column_name]))).sum() / len(df)

# %% [markdown]
# - Feature: `pers_sesso`

# %%
column = 'pers_sesso'
plot_pie(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_std(df, column)))
# Out:
# Missing pers_sesso: 0.00

# %% [markdown]
# - Feature: `pers_eta_ingresso_in_lista`

# %%
column = 'pers_eta_ingresso_in_lista'
plot_hist(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_std(df, column)))
# Out:
# Missing pers_eta_ingresso_in_lista: 0.00

# %% [markdown]
# - Feature: `diagnosi`

# %%
column = 'diagnosi'
if show_plot:
    plt.figure(figsize=(10, 10));
    plot_barh(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_std(df, column)))
# Out:
# Missing diagnosi: 0.05

# %% [markdown]
# - Feature: `lista_ingresso_data`

# %%
column = 'lista_ingresso_data'
plot_barv_date(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_std(df, column)))
# Out:
# Missing lista_ingresso_data: 0.00

# %% [markdown]
# - Feature: `tot_tx_organo`

# %%
column = 'tot_tx_organo'

if show_plot:    
    vc = df[column].value_counts(normalize=True)
    plt.barh(vc.index, vc.values, height=0.5, color='orange')
    locator = ticker.MultipleLocator(1)
    plt.gca().yaxis.set_major_locator(locator)
    
print('Missing {}: {:.2f}'.format(column, get_freq_nan_std(df, column)))
# Out:
# Missing tot_tx_organo: 0.20

# %% [markdown]
# - Feature: `tx_fegato_corrente`

# %%
column = 'tx_fegato_corrente'

if show_plot:    
    vc = df[column].value_counts(normalize=True)
    plt.barh(vc.index, vc.values, height=0.5, color='orange')
    locator = ticker.MultipleLocator(1)
    plt.gca().yaxis.set_major_locator(locator)

print('Missing {}: {:.2f}'.format(column, get_freq_nan_std(df, column)))
# Out:
# Missing tx_fegato_corrente: 0.20

# %% [markdown]
# Using SimpleImputer to remove NaN(s) values form _tot_tx_organo_ and _tx_fegato_corrente_:

# %%
imp = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
df[['tot_tx_organo', 'tx_fegato_corrente']] = imp.fit_transform(df[['tot_tx_organo', 'tx_fegato_corrente']])

# %%
print('Missing {}: {:.2f}'.format('tot_tx_organo', get_freq_nan_std(df, 'tot_tx_organo')))
print('Missing {}: {:.2f}'.format('tx_fegato_corrente', get_freq_nan_std(df, 'tx_fegato_corrente')))
# Out:
# Missing tot_tx_organo: 0.00
# Missing tx_fegato_corrente: 0.00

# %% [markdown]
# - Feature: `iscriz_tx_comb`

# %%
column = 'iscriz_tx_comb'
plot_pie(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_std(df, column)))
# Out:
# Missing iscriz_tx_comb: 0.00

# %% [markdown]
# - Feature: `tipo_combinato`

# %%
column = 'tipo_combinato'
plot_barh(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tipo_combinato(df)))
# Out:
# Missing tipo_combinato: 0.00

# %% [markdown]
# From a single column on the combined transplant we obtain 4 extra columns (_tx_rene_, _tx_pancreas_, _tx_intestino_, _tx_cuore_). The column _tx_fegato_ has no sense because all patients should have this field _true_.
#
# After this addition columns _iscriz_tx_comb_ and _tipo_combinato_ can be dropped.

# %%
df.insert(8, 'tx_rene', 0)
df.insert(8, 'tx_pancreas', 0)
df.insert(8, 'tx_intestino', 0)
df.insert(8, 'tx_cuore', 0)

# %%
organs = ['rene', 'pancreas', 'intestino', 'cuore']
for i in range(len(df)):
    if not pd.isna(df.iloc[i]['tipo_combinato']):
        for o in organs:
            if o in df.iloc[i]['tipo_combinato']:
                df.loc[i, 'tx_' + o] = 1

# %%
df.drop('iscriz_tx_comb', axis=1, inplace=True)
df.drop('tipo_combinato', axis=1, inplace=True)

# %% [markdown]
# - Feature: `ric_HBsAg` (Hepatitis B)

# %%
column = 'ric_HBsAg'
plot_pie(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_std(df, column)))
# Out:
# Missing ric_HBsAg: 0.04

# %% [markdown]
# - Feature: `ric_DELTA` (Hepatitis D)

# %%
column = 'ric_DELTA'
print('Missing {}: {:.2f}'.format(column, get_freq_nan_std(df, column)))
# Out:
# Missing ric_DELTA: 0.50

# %% [markdown]
# A lot of missing values, but it seems that Hepatitis D can only be present along with Hepatitis B. [1] So if `ric_HBsAg` is not detected (value `NO`) then `ric_DELTA` should not be present.

# %%
def exploit_dependence(row, dependent, independent):
    if pd.isna(row[dependent]) and row[independent] == 'NO':
        return 'NO'
    else:
        return row[dependent]

df['ric_DELTA'] = df.apply(lambda x: exploit_dependence(x, 'ric_DELTA', 'ric_HBsAg'), axis=1)

# %%
column = 'ric_DELTA'
plot_pie(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_std(df, column)))
# Out:
# Missing ric_DELTA: 0.05

# %% [markdown]
# - Feature: `ric_HCV` (Hepatitis C)

# %%
column = 'ric_HCV'
plot_pie(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_std(df, column)))
# Out:
# Missing ric_HCV: 0.04

# %% [markdown]
# - Feature: `ric_HCV_RNA`

# %%
column = 'ric_HCV_RNA'
print('Missing {}: {:.2f}'.format(column, get_freq_nan_std(df, column)))
# Out:
# Missing ric_HCV_RNA: 0.42

# %% [markdown]
# A lot of missing values, but it seems that Hepatitis C RNA can only be present along with Hepatitis C. [2] So if _ric_HCV_ is not detected (value _NO_) then _ric_HCV_RNA_ should not be present.

# %%
df['ric_HCV_RNA'] = df.apply(lambda x: exploit_dependence(x, 'ric_HCV_RNA', 'ric_HCV'), axis=1)

# %%
column = 'ric_HCV_RNA'
plot_pie(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_std(df, column)))
# Out:
# Missing ric_HCV_RNA: 0.06

# %% [markdown]
# - Feature: `ric_HIV`

# %%
column = 'ric_HIV'
plot_pie(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_std(df, column)))
# Out:
# Missing ric_HIV: 0.04

# %% [markdown]
# - Feature: `Peso`

# %%
column = 'Peso'
plot_hist(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_std(df, column)))
# Out:
# Missing Peso: 0.02

# %% [markdown]
# - Feature: `Altezza`

# %%
column = 'Altezza'
plot_hist(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_std(df, column)))
# Out:
# Missing Altezza: 0.02

# %% [markdown]
# - Feature: `BMI`

# %%
column = 'BMI'
plot_hist(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_std(df, column)))
# Out:
# Missing BMI: 0.02

# %% [markdown]
# - Feature: `MELD_in_ingresso`

# %%
column = 'MELD_in_ingresso'
plot_hist(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_std(df, column)))
# Out:
# Missing MELD_in_ingresso: 0.74

# %% [markdown]
# - Feature: `MELD_in_uscita`

# %%
column = 'MELD_in_uscita'
plot_hist(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_std(df, column)))
# Out:
# Missing MELD_in_uscita: 0.74

# %% [markdown]
# - Feature: `chirurgia_addom`

# %%
column = 'chirurgia_addom'
plot_pie(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_std(df, column)))
# Out:
# Missing chirurgia_addom: 0.04

# %% [markdown]
# - Feature: `trombosi_portale`

# %%
column = 'trombosi_portale'
plot_pie(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_std(df, column)))
# Out:
# Missing trombosi_portale: 0.04

# %% [markdown]
# - Feature: `TIPS`

# %%
column = 'TIPS'
plot_pie(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_std(df, column)))
# Out:
# Missing TIPS: 0.53

# %% [markdown]
# - Feature: `ric_diabete`

# %%
column = 'ric_diabete'
plot_pie(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_std(df, column)))
# Out:
# Missing ric_diabete: 0.22

# %% [markdown]
# - Feature: `HCC`

# %%
column = 'HCC'
plot_pie(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_std(df, column)))
# Out:
# Missing HCC: 0.03

# %% [markdown]
# **MELD** (Model End-stage Liver Disease) score is used to assess the severity of liver disease. [3] It can be used to estimate the survival of patients in list for a transplant: a lower score represents a lower mortality during a 3-month follow-up period. [4]
#
# `MELD = round(3.78*ln(a) + 11.2*ln(b) + 9.57*ln(c) + 6.43)`
#
# where `a`, `b`, `c` are patient's parameters obtained from a blood test that descrive how well the liver is working.
#
# Other (more accurate) scores are based on MELD:
# - MELD-Na
# - MELD-Plus
# - HCC-MELD

# %% [markdown]
# - Feature: `MELD_base`

# %%
column = 'MELD_base'
plot_hist(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_std(df, column)))
# Out:
# Missing MELD_base: 0.02

# %% [markdown]
# - Feature: `CHILD`
#
# Similar to the MELD score, the Child score assesses the condition of the patient based on 5 clinical measures. Each measure contributes to the final score with 1-3 points. The smaller is the score and the higher are the survival chances.

# %%
column = 'CHILD'
plt.hist(df[column].apply(lambda v: np.nan if pd.isna(v) else int(v[1:])-4), bins=11, edgecolor='black');
print('Missing {}: {:.2f}'.format(column, get_freq_nan_std(df, column)))
# Out:
# Missing CHILD: 0.24

# %% [markdown]
# - Feature: `MELD_na`

# %%
column = 'MELD_na'
plot_hist(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_std(df, column)))
# Out:
# Missing MELD_na: 0.93

# %% [markdown]
# - Feature: `MELD_HCC`

# %%
column = 'MELD_HCC'
plot_hist(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_std(df, column)))
# Out:
# Missing MELD_HCC: 0.86

# %% [markdown]
# - Feature: `AFP`

# %%
column = 'AFP'
plot_hist(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_std(df, column)))
# Out:
# Missing AFP: 0.73

# %% [markdown]
# - Feature: `dialisi_ultimi_15gg`

# %%
column = 'dialisi_ultimi_15gg'
plot_pie(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_std(df, column)))
# Out:
# Missing dialisi_ultimi_15gg: 0.51

# %% [markdown]
# - Feature: `lista_uscita_data`

# %%
column = 'lista_uscita_data'
plot_barv_date(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_std(df, column)))
# Out:
# Missing lista_uscita_data: 0.00

# %% [markdown]
# - Feature: `causa_uscita`

# %%
column = 'causa_uscita'
plot_barh(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_std(df, column)))
# Out:
# Missing causa_uscita: 0.00

# %% [markdown]
# - Feature: `data_decesso`

# %%
column = 'data_decesso'
plot_barv_date(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_data_decesso(df)))
# Out:
# Missing data_decesso: 0.00

# %% [markdown]
# - Feature: `UNOS`

# %%
column = 'UNOS'
plot_pie(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_std(df, column)))
# Out:
# Missing UNOS: 0.06

# %% [markdown]
# - Feature: `ISO2_super_urgenza`

# %%
column = 'ISO2_super_urgenza'
plot_pie(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_std(df, column)))
# Out:
# Missing ISO2_super_urgenza: 0.00

# %% [markdown]
# - Feature: `ric_ospedalizzazione_al_tx`

# %%
column = 'ric_ospedalizzazione_al_tx'
plot_pie(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing ric_ospedalizzazione_al_tx: 0.09

# %% [markdown]
# - Feature: `data_trapianto`

# %%
column = 'data_trapianto'
plot_barv_date(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing data_trapianto: 0.00

# %% [markdown]
# - Feature: `organo_trapiantato`

# %%
column = 'organo_trapiantato'
plot_pie(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing organo_trapiantato: 0.09

# %% [markdown]
# - Feature: `ischemia_fredda`

# %% [markdown]
# Convert the hh:mm:ss format into number of minutes for easier processing:

# %%
def process (x):
    if not pd.isna(x):
        spl = x.split(':')
        return int(spl[0])*60 + int(spl[1])
    return np.nan

df['ischemia_fredda'] = df['ischemia_fredda'].apply(process)

# %%
column = 'ischemia_fredda'
plot_hist(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing ischemia_fredda: 0.00

# %% [markdown]
# - Feature: `ric_ripresa_funzionale`

# %%
column = 'ric_ripresa_funzionale'
plot_pie(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing ric_ripresa_funzionale: 0.27

# %% [markdown]
# - Feature: `rigetto`

# %%
column = 'rigetto'
plot_pie(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing rigetto: 0.29

# %% [markdown]
# - Feature: `ultimo_stato_tx`

# %%
column = 'ultimo_stato_tx'
plot_barh(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing ultimo_stato_tx: 0.32

# %% [markdown]
# - Feature: `data_ultimo_agg_followup`

# %%
column = 'data_ultimo_agg_followup'
plot_barv_date(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing data_ultimo_agg_followup: 0.32

# %% [markdown]
# - Feature: `donatore_eta`

# %%
column = 'donatore_eta'
plot_hist(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing donatore_eta: 0.01

# %% [markdown]
# - Feature: `donatore_sesso`

# %%
column = 'donatore_sesso'
plot_pie(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing donatore_sesso: 0.01

# %% [markdown]
# - Feature: `donatore_caus_decesso`

# %%
column = 'donatore_caus_decesso'
plot_barh(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing donatore_caus_decesso: 0.01

# %% [markdown]
# - Feature: `tipo_donazione`

# %%
column = 'tipo_donazione'
plot_barh(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing tipo_donazione: 0.00

# %% [markdown]
# - Feature: `donatore_peso`

# %%
column = 'donatore_peso'
plot_hist(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing donatore_peso: 0.09

# %% [markdown]
# - Feature: `donatore_altezza`

# %%
column = 'donatore_altezza'
plot_hist(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing donatore_altezza: 0.09

# %% [markdown]
# - Feature: `donatore_BMI`

# %%
column = 'donatore_BMI'
plot_hist(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing donatore_BMI: 0.09

# %% [markdown]
# - Feature: `donatore_cardiopatia`

# %%
column = 'donatore_cardiopatia'
plot_pie(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing donatore_cardiopatia: 0.11

# %% [markdown]
# - Feature: `donatore_ipertensione`

# %%
column = 'donatore_ipertensione'
plot_pie(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing donatore_ipertensione: 0.10

# %% [markdown]
# - Feature: `donatore_diabete`

# %%
column = 'donatore_diabete'
plot_pie(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing donatore_diabete: 0.10

# %% [markdown]
# - Feature: `donatore_diabete_insulinodipendente`

# %%
column = 'donatore_diabete_insulinodipendente'
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing donatore_diabete_insulinodipendente: 0.25

# %% [markdown]
# Patients without diabetes (`donatore_diabete`) should have `NO` in this field:

# %%
df['donatore_diabete_insulinodipendente'] = df.apply(lambda x: exploit_dependence(x, 'donatore_diabete_insulinodipendente', 'donatore_diabete'), axis=1)

# %%
column = 'donatore_diabete_insulinodipendente'
plot_pie(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing donatore_diabete_insulinodipendente: 0.11

# %% [markdown]
# - Feature: `donatore_dislipidemie`

# %%
column = 'donatore_dislipidemie'
plot_pie(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing donatore_dislipidemie: 0.12

# %% [markdown]
# - Feature: `donatore_sodio`

# %%
column = 'donatore_sodio'
plt.figure(figsize=(16, 4))
if show_plot:
    for i in range(1, 4):
        plt.subplot(1, 3, i)
        plt.hist(data=df, x=column + str(i), bins=20, edgecolor='black');

for i in range(1, 4):
    print('Missing {}: {:.2f}'.format(column + str(i), get_freq_nan_tx(df, column + str(i))))
# Out:
# Missing donatore_sodio1: 0.20
# Missing donatore_sodio2: 0.25
# Missing donatore_sodio3: 0.37

# %% [markdown]
# To overcome the large number of missing values we can:
# - compute the mean over the valid measurements,
# - the average is `NaN` only if all values are `NaN`

# %%
def compute_mean(row, column):
    data = [row[column + str(1)], row[column + str(2)], row[column + str(3)]]
    total = np.nansum(data)
    count = (~np.isnan(data)).sum()
    
    if count == 0:
        return np.nan
    
    return total / count

# %%
index = df.columns.get_loc('donatore_sodio3')+1
df.insert(index, 'donatore_sodio_avg', False)

df['donatore_sodio_avg'] = df.apply(lambda x: compute_mean(x, 'donatore_sodio'), axis=1)

# %%
df.drop('donatore_sodio1', axis=1, inplace=True)
df.drop('donatore_sodio2', axis=1, inplace=True)
df.drop('donatore_sodio3', axis=1, inplace=True)

# %%
column = 'donatore_sodio_avg'
plot_hist(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing donatore_sodio_avg: 0.10

# %% [markdown]
# - Feature: `donatore_AST`

# %%
column = 'donatore_AST'

plt.figure(figsize=(16, 4))

if show_plot:
    for i in range(1, 4):
        plt.subplot(1, 3, i)
        plt.hist(data=df, x=column + str(i), bins=20, edgecolor='black');

# %%
df.loc[df['donatore_AST1'] > 1000, ['donatore_AST1', 'donatore_AST2', 'donatore_AST3']]
# Out:
#       donatore_AST1  donatore_AST2  donatore_AST3
# 195          1218.0          521.0            NaN
# 584          1378.0          427.0          303.0
# 647          1159.0          923.0            NaN
# 1756         6538.0         9001.0         6021.0
# 2231         1154.0         1060.0            NaN

# %% [markdown]
# Remove extreme values:

# %%
index1 = df.loc[df['donatore_AST1'] > 1000].index
index2 = df.loc[df['donatore_AST2'] > 1000].index
index3 = df.loc[df['donatore_AST3'] > 1000].index

df.loc[index1, 'donatore_AST1'] = np.nan
df.loc[index2, 'donatore_AST2'] = np.nan
df.loc[index3, 'donatore_AST3'] = np.nan

# %%
column = 'donatore_AST'

plt.figure(figsize=(16, 4))

if show_plot:
    for i in range(1, 4):
        plt.subplot(1, 3, i)
        plt.hist(data=df, x=column + str(i), bins=20, edgecolor='black');
    
for i in range(1, 4):
    print('Missing {}: {:.2f}'.format(column + str(i), get_freq_nan_tx(df, column + str(i))))
# Out:
# Missing donatore_AST1: 0.31
# Missing donatore_AST2: 0.32
# Missing donatore_AST3: 0.40

# %% [markdown]
# To overcome the large number of missing values we can calculate the mean over the three measurements:

# %%
index = df.columns.get_loc('donatore_AST3')+1
df.insert(index, 'donatore_AST_avg', False)

df['donatore_AST_avg'] = df.apply(lambda x: compute_mean(x, 'donatore_AST'), axis=1)

df.drop('donatore_AST1', axis=1, inplace=True)
df.drop('donatore_AST2', axis=1, inplace=True)
df.drop('donatore_AST3', axis=1, inplace=True)

# %%
column = 'donatore_AST_avg'
plot_hist(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing donatore_AST_avg: 0.12

# %% [markdown]
# - Feature: `donatore_ALT`

# %%
column = 'donatore_ALT'

plt.figure(figsize=(16, 4))

if show_plot:
    for i in range(1, 4):
        plt.subplot(1, 3, i)
        plt.hist(data=df, x=column + str(i), bins=20, edgecolor='black');

# %%
df.loc[df['donatore_ALT3'] > 1000, ['donatore_ALT1', 'donatore_ALT2', 'donatore_ALT3']]
# Out:
#       donatore_ALT1  donatore_ALT2  donatore_ALT3
# 1502          523.0            NaN         1122.0
# 1756         9629.0         9048.0         8449.0
# 2183            NaN          324.0         1857.0

# %% [markdown]
# Remove extreme values:

# %%
index1 = df.loc[df['donatore_ALT1'] > 1000].index
index2 = df.loc[df['donatore_ALT2'] > 1000].index
index3 = df.loc[df['donatore_ALT3'] > 1000].index

df.loc[index1, 'donatore_ALT1'] = np.nan
df.loc[index2, 'donatore_ALT2'] = np.nan
df.loc[index3, 'donatore_ALT3'] = np.nan

# %%
column = 'donatore_ALT'

plt.figure(figsize=(16, 4))

if show_plot:
    for i in range(1, 4):
        plt.subplot(1, 3, i)
        plt.hist(data=df, x=column + str(i), bins=20, edgecolor='black');
    
for i in range(1, 4):
    print('Missing {}: {:.2f}'.format(column + str(i), get_freq_nan_tx(df, column + str(i))))
# Out:
# Missing donatore_ALT1: 0.25
# Missing donatore_ALT2: 0.29
# Missing donatore_ALT3: 0.38

# %% [markdown]
# To overcome the large number of missing values we can calculate the mean over the three measurements:

# %%
index = df.columns.get_loc('donatore_ALT3')+1
df.insert(index, 'donatore_ALT_avg', False)

df['donatore_ALT_avg'] = df.apply(lambda x: compute_mean(x, 'donatore_ALT'), axis=1)

df.drop('donatore_ALT1', axis=1, inplace=True)
df.drop('donatore_ALT2', axis=1, inplace=True)
df.drop('donatore_ALT3', axis=1, inplace=True)

# %%
column = 'donatore_ALT_avg'
plot_hist(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing donatore_ALT_avg: 0.10

# %% [markdown]
# - Feature: `donatore_bilirubinaTot`

# %%
column = 'donatore_bilirubinaTot'

plt.figure(figsize=(16, 4))

if show_plot:
    for i in range(1, 4):
        plt.subplot(1, 3, i)
        plt.hist(data=df, x=column + str(i), bins=20, edgecolor='black');

# %%
df.loc[df['donatore_bilirubinaTot3'] > 20, ['donatore_bilirubinaTot1', 'donatore_bilirubinaTot2', 'donatore_bilirubinaTot3']]
# Out:
#       donatore_bilirubinaTot1  donatore_bilirubinaTot2  \
# 1457                     0.51                      NaN
#
#       donatore_bilirubinaTot3
# 1457                     92.0

# %% [markdown]
# Remove extreme values:

# %%
index1 = df.loc[df['donatore_bilirubinaTot1'] > 20].index
index2 = df.loc[df['donatore_bilirubinaTot2'] > 20].index
index3 = df.loc[df['donatore_bilirubinaTot3'] > 20].index

df.loc[index1, 'donatore_bilirubinaTot1'] = np.nan
df.loc[index2, 'donatore_bilirubinaTot2'] = np.nan
df.loc[index3, 'donatore_bilirubinaTot3'] = np.nan

# %%
column = 'donatore_bilirubinaTot'

plt.figure(figsize=(16, 4))

if show_plot:
    for i in range(1, 4):
        plt.subplot(1, 3, i)
        plt.hist(data=df, x=column + str(i), bins=20, edgecolor='black')
        
for i in range(1, 4):
    print('Missing {}: {:.2f}'.format(column + str(i), get_freq_nan_tx(df, column + str(i))))
# Out:
# Missing donatore_bilirubinaTot1: 0.29
# Missing donatore_bilirubinaTot2: 0.31
# Missing donatore_bilirubinaTot3: 0.40

# %% [markdown]
# To overcome the large number of missing values we can calculate the mean over the three measurements:

# %%
index = df.columns.get_loc('donatore_bilirubinaTot3')+1
df.insert(index, 'donatore_bilirubinaTot_avg', False)

df['donatore_bilirubinaTot_avg'] = df.apply(lambda x: compute_mean(x, 'donatore_bilirubinaTot'), axis=1)

df.drop('donatore_bilirubinaTot1', axis=1, inplace=True)
df.drop('donatore_bilirubinaTot2', axis=1, inplace=True)
df.drop('donatore_bilirubinaTot3', axis=1, inplace=True)

# %%
column = 'donatore_bilirubinaTot_avg'
plot_hist(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing donatore_bilirubinaTot_avg: 0.10

# %% [markdown]
# - Feature: `donatore_fosfatasi`

# %%
column = 'donatore_fosfatasi'

plt.figure(figsize=(16, 4))

if show_plot:
    for i in range(1, 4):
        plt.subplot(1, 3, i)
        plt.hist(data=df, x=column + str(i), bins=20, edgecolor='black')
        
for i in range(1, 4):
    print('Missing {}: {:.2f}'.format(column + str(i), get_freq_nan_tx(df, column + str(i))))
# Out:
# Missing donatore_fosfatasi1: 0.49
# Missing donatore_fosfatasi2: 0.39
# Missing donatore_fosfatasi3: 0.47

# %% [markdown]
# To overcome the large number of missing values we can calculate the mean over the three measurements:

# %%
index = df.columns.get_loc('donatore_fosfatasi3')+1
df.insert(index, 'donatore_fosfatasi_avg', False)

df['donatore_fosfatasi_avg'] = df.apply(lambda x: compute_mean(x, 'donatore_fosfatasi'), axis=1)

df.drop('donatore_fosfatasi1', axis=1, inplace=True)
df.drop('donatore_fosfatasi2', axis=1, inplace=True)
df.drop('donatore_fosfatasi3', axis=1, inplace=True)

# %%
column = 'donatore_fosfatasi_avg'
plot_hist(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing donatore_fosfatasi_avg: 0.19

# %% [markdown]
# - Feature: `donatore_gammaGT`

# %%
column = 'donatore_gammaGT'

plt.figure(figsize=(16, 4))

if show_plot:
    for i in range(1, 4):
        plt.subplot(1, 3, i)
        plt.hist(data=df, x=column + str(i), bins=20, edgecolor='black')
        
for i in range(1, 4):
    print('Missing {}: {:.2f}'.format(column + str(i), get_freq_nan_tx(df, column + str(i))))
# Out:
# Missing donatore_gammaGT1: 0.45
# Missing donatore_gammaGT2: 0.37
# Missing donatore_gammaGT3: 0.45

# %% [markdown]
# To overcome the large number of missing values we can calculate the mean over the three measurements:

# %%
index = df.columns.get_loc('donatore_gammaGT3')+1
df.insert(index, 'donatore_gammaGT_avg', False)

df['donatore_gammaGT_avg'] = df.apply(lambda x: compute_mean(x, 'donatore_gammaGT'), axis=1)

df.drop('donatore_gammaGT1', axis=1, inplace=True)
df.drop('donatore_gammaGT2', axis=1, inplace=True)
df.drop('donatore_gammaGT3', axis=1, inplace=True)

# %%
column = 'donatore_gammaGT_avg'
plot_hist(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing donatore_gammaGT_avg: 0.14

# %% [markdown]
# - Feature: `donatore_arresto_cardiaco`

# %%
column = 'donatore_arresto_cardiaco'
plot_pie(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing donatore_arresto_cardiaco: 0.11

# %% [markdown]
# - Feature: `donatore_hcv`

# %%
column = 'donatore_hcv'
plot_pie(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing donatore_hcv: 0.09

# %% [markdown]
# - Feature: `donatore_hcv_rna`

# %%
column = 'donatore_hcv_rna'
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing donatore_hcv_rna: 0.25

# %% [markdown]
# Like before, Hepatitis C RNA can only be present along with Hepatitis C. So if `donatore_hcv` is not detected (value `NEG`) then `donatore_hcv_rna` should not be present.

# %%
for i in range(len(df)):
    if pd.isna(df.iloc[i]['donatore_hcv_rna']) and df.iloc[i]['donatore_hcv'] == 'NEG':
        df.loc[i, 'donatore_hcv_rna'] = 'NEG'

# %%
column = 'donatore_hcv_rna'
plot_pie(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing donatore_hcv_rna: 0.09

# %% [markdown]
# - Feature: `donatore_HBsAg`

# %%
column = 'donatore_HBsAg'
plot_barh(df[column], show_plot)

# %%
df.loc[df['donatore_HBsAg'] == 'in corso', 'donatore_HBsAg'] = np.nan

# %%
column = 'donatore_HBsAg'
plot_pie(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing donatore_HBsAg: 0.09

# %% [markdown]
# - Feature: `donatore_HBsAb`

# %%
column = 'donatore_HBsAb'
plot_pie(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing donatore_HBsAb: 0.24

# %% [markdown]
# - Feature: `donatore_HBeAb`

# %%
column = 'donatore_HBeAb'
plot_pie(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing donatore_HBeAb: 0.56

# %% [markdown]
# - Feature: `donatore_antiCoreTot`

# %%
column = 'donatore_antiCoreTot'
plot_pie(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing donatore_antiCoreTot: 0.09

# %% [markdown]
# - Feature: `donatore_hbv_dna`

# %%
column = 'donatore_hbv_dna'
plot_barh(df[column], show_plot)

# %%
values_to_remove = ['non richiesto', 'non dosabile', 'non eseguito']
df.loc[df['donatore_hbv_dna'].isin(values_to_remove) , 'donatore_hbv_dna'] = np.nan

# %%
column = 'donatore_hbv_dna'
plot_pie(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing donatore_hbv_dna: 0.28

# %% [markdown]
# - Feature: `donatore_hcv_rna`

# %%
values_to_remove = ['non richiesto', 'non dosabile', 'non eseguito']
df.loc[df['donatore_hcv_rna'].isin(values_to_remove) , 'donatore_hcv_rna'] = np.nan

# %%
column = 'donatore_hcv_rna'
plot_pie(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing donatore_hcv_rna: 0.12

# %% [markdown]
# - Feature: `donatore_steatosiMacro`

# %%
column = 'donatore_steatosiMacro'
plot_hist(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing donatore_steatosiMacro: 0.29

# %% [markdown]
# - Feature: `donatore_livelloRischioPreLT`

# %%
column = 'donatore_livelloRischioPreLT'
plot_barh(df[column], show_plot)

# %%
df.loc[df['donatore_livelloRischioPreLT'] == 'Non valutabile', 'donatore_livelloRischioPreLT'] = np.nan
df.loc[df['donatore_livelloRischioPreLT'].str.contains('NON STANDARD', na=False), 'donatore_livelloRischioPreLT'] = 'Non standard'

# %%
column = 'donatore_livelloRischioPreLT'
plot_barh(df[column], show_plot)
print('Missing {}: {:.2f}'.format(column, get_freq_nan_tx(df, column)))
# Out:
# Missing donatore_livelloRischioPreLT: 0.13

# %% [markdown]
# ### Removing columns with too many missing values

# %% [markdown]
# The columns with more than 30% `NaN` are removed because they contain too many missing values:

# %%
df = df.drop(columns=['MELD_in_ingresso', 'MELD_in_uscita', 'MELD_na', 'MELD_HCC', 'AFP', 'donatore_HBeAb'])

# %% [markdown]
# <h2><span style="color:#191996">5. Creation of X and y</span></h2>

# %% [markdown]
# For **estimating the 5-year survival**, only `causa_uscita = TX nel centro di iscrizione` is considered:

# %%
df_tx = df[df['causa_uscita'] == 'TX nel centro di iscrizione'].drop(columns=['causa_uscita'])

print('Number of patients: {}'.format(len(df_tx)))
# Out:
# Number of patients: 1423

# %% [markdown]
# ### Creating X

# %%
X = df_tx.copy(deep=True)

# %%
# drop useless dates
X = X.drop(columns=['lista_ingresso_data', 'lista_uscita_data'])

# very limited number of patients (5) have ISO2_super_urgenza: dropping the column
X = X.drop(columns=['ISO2_super_urgenza'])

# very limited number of patients (5) have rigetto: dropping the column
X = X.drop(columns=['rigetto'])

# very limited number of patients (11) have tipo_donazione != Cadavere: dropping the column
X = X.drop(columns=['tipo_donazione'])

# a single patient has donatore_arresto_cardiaco == Irreversibile: dropping it
idx = X.loc[X['donatore_arresto_cardiaco'] == 'Irreversibile'].index
X = X.drop(idx, axis=0)

# %%
print("Large number of diagnosis ({}), the 4 most frequent (Epatocarcinoma associato a cirrosi, Cirrosi postnecrotica da HCV, Cirrosi di Laennec (post-alcolica), Ritrapianto/rigetto di trapianto epatico) are kept, the others are considered together with value Altro".format(len(X['diagnosi'].value_counts().index)))
# Out:
# Large number of diagnosis (46), the 4 most frequent (Epatocarcinoma associato a cirrosi, Cirrosi postnecrotica da HCV, Cirrosi di Laennec (post-alcolica), Ritrapianto/rigetto di trapianto epatico) are kept, the others are considered together with value Altro

# %%
# nan are kept and not encoded as 'Altro'
diagnosis_to_keep = [np.nan, 'Epatocarcinoma associato a cirrosi', 'Cirrosi postnecrotica da HCV', 'Cirrosi di Laennec (post-alcolica)', 'Ritrapianto/rigetto di trapianto epatico']

X['diagnosi'] = X['diagnosi'].apply(lambda d: 'Altro' if d not in diagnosis_to_keep else d)

# %%
plot_barh(X['diagnosi'], True)

# %%
print("Large number of donatore_caus_decesso ({}), the 4 most frequent (Emorragia cerebrale, Trauma cranico, Encefalopatia post-anossica, Ictus ischemico) are kept, the others are considered together with value Altro".format(len(X['donatore_caus_decesso'].value_counts().index)))
# Out:
# Large number of donatore_caus_decesso (10), the 4 most frequent (Emorragia cerebrale, Trauma cranico, Encefalopatia post-anossica, Ictus ischemico) are kept, the others are considered together with value Altro

# %%
# nan are kept and not encoded as 'Altro'
caus_decesso_to_keep = [np.nan, 'Emorragia cerebrale', 'Trauma cranico', 'Encefalopatia post-anossica', 'Ictus ischemico']

X['donatore_caus_decesso'] = X['donatore_caus_decesso'].apply(lambda d: 'Altro' if d not in caus_decesso_to_keep else d)

# %%
plot_barh(X['donatore_caus_decesso'], True)

# %% [markdown]
# ### Encoding X
# One-hot encoding for `diagnosi`:

# %%
def one_hot_nan (row, column_names):
    if row[column_names].sum() == 0:
        # all the values are 0 -> one hot encoding of nan
        return [np.nan]*len(column_names)
    else:
        return row[column_names]

# %%
dummy = pd.get_dummies(X['diagnosi'], dummy_na=True)

X['diagnosi_epatocarcinoma'] = dummy['Epatocarcinoma associato a cirrosi']
X['diagnosi_cirrosi_hcv'] = dummy['Cirrosi postnecrotica da HCV']
X['diagnosi_cirrosi_laennec'] = dummy['Cirrosi di Laennec (post-alcolica)']
X['diagnosi_ritrapianto_rigetto'] = dummy['Ritrapianto/rigetto di trapianto epatico']
X['diagnosi_altro'] = dummy['Altro']

columns = ['diagnosi_epatocarcinoma', 'diagnosi_cirrosi_hcv', 'diagnosi_cirrosi_laennec', 'diagnosi_ritrapianto_rigetto', 'diagnosi_altro']
        
X[columns] = X[columns].apply(lambda row: one_hot_nan(row, columns), axis=1)

# column diagnosi can be dropped
X = X.drop(columns=['diagnosi'])

# %% [markdown]
# One-hot encoding for `donatore_caus_decesso`:

# %%
dummy = pd.get_dummies(X['donatore_caus_decesso'])

X['donatore_caus_decesso_emorragia'] = dummy['Emorragia cerebrale']
X['donatore_caus_decesso_trauma'] = dummy['Trauma cranico']
X['donatore_caus_decesso_encefalopatia'] = dummy['Encefalopatia post-anossica']
X['donatore_caus_decesso_ictus'] = dummy['Ictus ischemico']
X['donatore_caus_decesso_altro'] = dummy['Altro']

columns = ['donatore_caus_decesso_emorragia', 'donatore_caus_decesso_trauma', 'donatore_caus_decesso_encefalopatia', 'donatore_caus_decesso_ictus', 'donatore_caus_decesso_altro']

X[columns] = X[columns].apply(lambda row: one_hot_nan(row, columns), axis=1)

# column donatore_caus_decesso can be dropped
X = X.drop(columns=['donatore_caus_decesso'])

# %% [markdown]
# Decision Trees work well with categorical variables, but to perform missing values imputation we need to encode the categorical variables.
#
# `M`/`F` needs to be encoded with `0`/`1`, same for `NO`/`SI` and `NEG`/`POS`:

# %%
def encode_01 (value):
    if value == 'M' or value == 'NO' or value == 'NEG':
        return 0
    elif value == 'F' or value == 'SI' or value == 'POS':
        return 1
    elif pd.isna(value):
        return np.nan
    else:
        raise ValueError("{} can not be encoded with the specified rules!".format(value))

columns_to_encode = ['pers_sesso', 'ric_HBsAg', 'ric_DELTA', 'ric_HCV', 'ric_HCV_RNA', 'ric_HIV', 'chirurgia_addom', 'TIPS', 'ric_diabete', 'HCC', 'dialisi_ultimi_15gg', 'donatore_sesso', 'donatore_cardiopatia', 'donatore_ipertensione', 'donatore_diabete', 'donatore_diabete_insulinodipendente', 'donatore_dislipidemie', 'donatore_hcv', 'donatore_HBsAg', 'donatore_HBsAb', 'donatore_antiCoreTot', 'donatore_hbv_dna', 'donatore_hcv_rna']
for c in columns_to_encode:
    X[c] = X[c].apply(encode_01)

# %%
# encoding for ric_ripresa_funzionale (Ripresa immediata / PGNF) and donatore_arresto_cardiaco (NO / SI (recuperato))
X['ric_ripresa_funzionale'] = X['ric_ripresa_funzionale'].apply(lambda v: 0 if v == 'Ripresa immediata' else 1)
X['donatore_arresto_cardiaco'] = X['donatore_arresto_cardiaco'].apply(lambda v: 0 if v == 'NO' else 1)

# %% [markdown]
# Ordinal encoding for `trombosi_portale`, `UNOS`, `CHILD`:

# %%
def encode_ordinal (value, dictionary):
    if not pd.isna(value):
        return dictionary[value]
    else:
        return np.nan

# %%
d = {'NO': 0, 'PARZIALE': 1, 'SI': 2}
X['trombosi_portale'] = X['trombosi_portale'].apply(lambda v: encode_ordinal(v, d))

d = {'3': 1, '2B': 2, '2A': 3, '1': 4}
X['UNOS'] = X['UNOS'].apply(lambda v: encode_ordinal(v, d))

d = {'A5': 1, 'A6': 2, 'B7': 3, 'B8': 4, 'B9': 5, 'C10': 6, 'C11': 7, 'C12': 8, 'C13': 9, 'C14': 10, 'C15': 11}
X['CHILD'] = X['CHILD'].apply(lambda v: encode_ordinal(v, d))

# %% [markdown]
# Ordinal encoding for `ric_ospedalizzazione_al_tx`, `organo_trapiantato`, `donatore_livelloRischioPreLT`:

# %%
d = {'Non Ospedalizzato': 0, 'Ospedalizzato In Reparto': 1, 'Ospedalizzato In Terapia Intensiva / Rianimazione': 2}
X['ric_ospedalizzazione_al_tx'] = X['ric_ospedalizzazione_al_tx'].apply(lambda v: encode_ordinal(v, d))

d = {'Fegato intero': 0, 'Fegato split Sx': 1, 'Fegato split Dx': 1} # split sx and split dx merged together
X['organo_trapiantato'] = X['organo_trapiantato'].apply(lambda v: encode_ordinal(v, d))

d = {'Standard': 1, 'Non standard': 2, 'Calcolato': 3, 'Aumentato ma accettabile': 4}
X['donatore_livelloRischioPreLT'] = X['donatore_livelloRischioPreLT'].apply(lambda v: encode_ordinal(v, d))

# %% [markdown]
# ### Creating label y

# %%
def obtain_label (row, years):
    # based on the transplant date and on the update information known
    # 0 -> patient died before <years>
    # 1 -> patient survived at least <years>
    
    tx_date = row['data_trapianto']    
    death_date = None
    
    if not pd.isna(row['data_decesso']):
        death_date = row['data_decesso']        
    elif pd.isna(row[['data_ultimo_agg_followup', 'ultimo_stato_tx']]).tolist() == [False, False] \
            and row['ultimo_stato_tx'] == 'Paziente deceduto':
        death_date = row['data_ultimo_agg_followup']
    
    if death_date != None:
        delta_days = (death_date - tx_date).days        
        if delta_days < 365*years:
            return 0
    
    # seems alive
    return 1

# %%
years = 5

y = X.apply(lambda row: obtain_label(row, years), axis=1)

# we can now drop 'data_decesso', 'data_ultimo_agg_followup', 'ultimo_stato_tx', 'data_trapianto'
X = X.drop(columns=['data_decesso', 'data_ultimo_agg_followup', 'ultimo_stato_tx', 'data_trapianto'])

# %%
plot_pie(y, True)

# %% [markdown]
# Creating train and test split:

# %%
X_train_nan, X_test_nan, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

y_train = np.array(y_train).ravel()
y_test = np.array(y_test).ravel()

print("X train length: {}\nX test length: {}".format(len(X_train_nan), len(X_test_nan)))
# Out:
# X train length: 1137
# X test length: 285

# %% [markdown]
# ### Iterative Imputation
# It seems that the missing data are Missing Completely At Random (MCAR):
# \begin{equation}
# P(m | X_k, X_m) = P(m)
# \end{equation}
#
# But a more conservative assumption is Missing At Random (MAR):
# \begin{equation}
# P(m | X_k, X_m) = P(m | X_k)
# \end{equation}
#
# With MAR data we can use the `IterativeImputer`:
#
# > A strategy for imputing missing values by modeling each feature as a function of other features in a round-robin fashion.

# %% [markdown]
# Given:
# - an estimator $E$;
# - known data $X^k$ and missing data $X^m$;
# - a tolerance $tol$;
# - a maximum number of iterations $max\_iter$
#
# The missing values are estimated in a _round-robin_ fashion:
#
# 1. Initially replace all the missing values with values derived solely from non-missing values of the considered feature $c$:
# \begin{equation}
# for\;i=1..u\;\;X^m_{c, i} = \underset{j=1..n}{\operatorname{avg(X^k_{c, j})}}
# \end{equation}
# 2. Starting from a feature $c$, train $E$ on the other features:
# \begin{equation}
# E.fit(X^k_{f \ne c}, X^k_{f=c})
# \end{equation}
# 3. Use the fitted estimator to predict the missing values of feature $c$:
# \begin{equation}
# X^m_{f=c} = E.predict(X^m_{f \ne c})
# \end{equation}
# 4. Repeat step 2 and 3 for every feature $c$ containing missing values
#
# Cycle $max\_iter$ times from step 2 to 4. Stop earlier if
# \begin{equation}
# \frac{max{|X^{m,t} - X^{m,{t-1}}|}}{max{|X^k|}} < tol
# \end{equation}
# where $X^{m,t}$ is $X^m$ at iteration $t$

# %% [markdown]
# Missing value imputation using `IterativeImputer`:

# %%
imputer = IterativeImputer(max_iter=20,
                           min_value=get_min_value(),
                           max_value=get_max_value(),
                           random_state=seed)
imputer.fit(X_train_nan);

# %%
X_train_imputed_array = imputer.transform(X_train_nan)
X_test_imputed_array = imputer.transform(X_test_nan)

X_train = pd.DataFrame(X_train_imputed_array, index=X_train_nan.index, columns=X_train_nan.columns)
X_test = pd.DataFrame(X_test_imputed_array, index=X_test_nan.index, columns=X_test_nan.columns)

# %% [markdown]
# After the imputation, intermediate values are not rounded because this additional information can be useful for the classifier.

# %%
column = 'MELD_base'
X_train[pd.isna(X_train_nan[column])][column].head(10)
# Out:
# 1329    36.438298
# 1317    33.285712
# 26      21.890872
# 1311    36.829147
# 1307    30.502734
# 1312    31.285613
# 1320    32.123120
# 1289    22.910498
# 1302    32.892821
# 1297    22.785558
# Name: MELD_base, dtype: float64

# %% [markdown]
# <h2><span style="color:#191996">6. Training the classifiers</span></h2>

# %% [markdown]
# In this application, evaluating a classifier using its accuracy is not totally correct: different errors have different costs. Instead, we are interested in minimizing a loss (or cost) that tell us how well our model is performing. The cost matrix is defined as:

# %%
cost_matrix = {'TP': 0, 'TN': 0, 'FP': 8, 'FN': 1}

# %% [markdown]
# It is fair to assume that the cost associated with a `False Positive` is higher than the cost associated with a `False Negative`. Still, these numbers should come from an expert. Those proposed are only a guess for the purpose of the study.

# %% [markdown]
# A custom score function (that depends on the cost matrix above) is created:

# %%
custom_score = make_scorer(get_cost, greater_is_better=False, cost_matrix=cost_matrix)

# %% [markdown]
# ### Dummy Classifier
# Classifier that makes predictions using simple rules, like:
# - always predict `most frequent` class (default)
# - random predictions according to the class distribution (`stratified`)
# - predictions uniformly at random (`uniform`)
#
# Useful as a simple **baseline**.

# %%
dummy = DummyClassifier(random_state=seed)
dummy.fit(X_train, y_train)
print('Dummy classifier cost (train): {}'.format(-custom_score(dummy, X_train, y_train)))
print('Dummy classifier cost (test): {}'.format(-custom_score(dummy, X_test, y_test)))
# Out:
# Dummy classifier cost (train): 1864
# Dummy classifier cost (test): 464

# %%
plot_confusion_matrix(dummy, X_test, y_test);

# %% [markdown]
# ### Random Forest Classifier
# - Ensemble of _n_ Decision Trees: $T_1$ ... $T_n$
# - $T_i$ is trained on $D_i$
# - $D_i$ is obtained by sampling with replacement from the original dataset $D$ (_boostrap aggregating_, `bootstrap = True` parameter)
# - each tree cast a vote for the prediction
#
# This technique reduces the variance without increasing the bias as long as the trees are uncorrelated.
#
# If a particular subset of features is particularly predictive, the trees could remain correlated: Random Forest trees use a random subset of features for each split (`max_features` parameter).

# %% [markdown]
# #### Cross-validation on Random Forest

# %%
param_grid = [{
    'criterion': ['gini', 'entropy'],
    'max_depth': list(range(1, 51)),
    'min_samples_split': list(range(2, 6)),
    'max_features': ['sqrt', 'log2', None],
    'bootstrap': [True, False]
}]

classifier = RandomForestClassifier(class_weight={1: 1, 0: 1}, random_state=seed)

grid_search = GridSearchCV(classifier, param_grid, scoring=custom_score, cv=5, n_jobs=4)

grid_search.fit(X_train, y_train)

print(grid_search.best_score_)
print(grid_search.best_params_)
# Out:
# -302.0
# {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 12, 'max_features': None, 'min_samples_split': 5}

# %%
cls_forest = RandomForestClassifier(criterion = 'entropy',
                                    max_depth = 12,
                                    bootstrap = False,     # no boostrap aggregating
                                    max_features = None,   # all the features are used at each split
                                    min_samples_split = 5, # min number of samples to create a split
                                    random_state = seed)

cls_forest.fit(X_train, y_train)

print('Random Forest cost (train): {}'.format(-custom_score(cls_forest, X_train, y_train)))
print('Random Forest cost (test): {}'.format(-custom_score(cls_forest, X_test, y_test)))
# Out:
# Random Forest cost (train): 557
# Random Forest cost (test): 412

# %%
plot_confusion_matrix(cls_forest, X_test, y_test);

# %% [markdown]
# ### Extra Trees Classifier
#
# Similar to the Random Forest classifier, but with some differences [5]:
# - generally `bootstrap = False`, so each tree is trained on the whole dataset
# - at each node, propose a random splits for each feature: the best split is used

# %% [markdown]
# #### Cross-validation on Extra Trees

# %%
param_grid = [{
    'criterion': ['gini', 'entropy'],
    'max_depth': list(range(1, 51)),
    'min_samples_split': list(range(2, 6)),
    'max_features': ['sqrt', 'log2', None],
    'bootstrap': [True, False]
}]

classifier = ExtraTreesClassifier(class_weight={1: 1, 0: 1}, random_state=seed)

grid_search = GridSearchCV(classifier, param_grid, scoring=custom_score, cv=5, n_jobs=4)

grid_search.fit(X_train, y_train)

print(grid_search.best_score_)
print(grid_search.best_params_)
# Out:
# -325.2
# {'bootstrap': False, 'criterion': 'gini', 'max_depth': 22, 'max_features': None, 'min_samples_split': 2}

# %%
cls_extra = ExtraTreesClassifier(criterion = 'gini',
                                 max_depth = 22,
                                 bootstrap = False,     # no boostrap aggregating
                                 max_features = None,   # all the features are used at each split
                                 min_samples_split = 2, # min number of samples to create a split
                                 random_state = seed)

cls_extra.fit(X_train, y_train)

print('Extra Trees cost (train): {}'.format(-custom_score(cls_extra, X_train, y_train)))
print('Extra Trees cost (test): {}'.format(-custom_score(cls_extra, X_test, y_test)))
# Out:
# Extra Trees cost (train): 0
# Extra Trees cost (test): 389

# %%
plot_confusion_matrix(cls_extra, X_test, y_test);

# %% [markdown]
# ### Comparison
#
# It seems that the increased randomization used by the Extra Trees is beneficial.
#
# Apart from depth, there are no other very important differences between the Random Fores and the Extra Trees used above as both are trained without bootstrap aggregating on the whole set of features.
#
# | Classifier    | Cost (test set)|
# |---------------|----------------|
# | Dummy         | 464            |
# | Random Forest | 412            |
# | Extra Trees   | 389            |

# %% [markdown]
# ### Feature importance with boruta

# %% [markdown]
# **Boruta** is a powerful feature selection algorithm:
# - based on Random Forest
# - works well without tuning
#
# The algorithm:
#
# 1. For each feature $f_j$ a _shadown feature_ $s_j$ is created making a copy of $f_j$'s values and shuffling them (to remove their correlations with y). This way the number of features doubles;
# 2. Train a Random Forest classifier on the extended dataset. Only the features that are more important than the most important shadow feature score a point (hit);
# 3. Repeat step 1-2 `max_iter` times accumulating hits;
# 4. At the end, depending on the accumulated hits, each feature $f_j$ has support (or weak support) or not.

# %%
forest = RandomForestClassifier(max_depth=5, n_jobs=4, random_state=seed)
boruta = BorutaPy(estimator=forest, n_estimators='auto', max_iter=100, random_state=seed)

boruta.fit(np.array(X_train), y_train);

# %%
X_train.columns[boruta.support_].to_list()
# Out:
# ['BMI',
#  'MELD_base',
#  'dialisi_ultimi_15gg',
#  'donatore_bilirubinaTot_avg',
#  'donatore_gammaGT_avg']

# %%
X_train.columns[boruta.support_weak_].to_list()
# Out:
# ['ric_HCV_RNA', 'CHILD']

# %% [markdown]
# # Extra: project work

# %% [markdown]
# #### 1) Is there strong correlation between the MELD score and the fact that the patient received a transplant?

# %%
plot_barh(df['causa_uscita'], True)

# %%
tx_meld = df[['causa_uscita', 'MELD_base']]

# %%
tx = ['TX nel centro di iscrizione',
      'Trapiantato da VIVENTE in questo Centro',
      'Trapianto in altra sede non specificata',
      'Trapianto AIRT fuori Regione']
no_tx = ['Deceduto iscritto in lista',
         'Non idoneo clinicamente']

def tx_no_tx (row, tx, no_tx):
    # 0: did not receive a transplant
    # 1: received a transplant
    if row['causa_uscita'] in no_tx:
        return 0
    elif row['causa_uscita'] in tx:
        return 1
    else:
        # other value
        return 2

# %%
tx_meld['transplant_done'] = tx_meld.apply(lambda x: tx_no_tx(x, tx, no_tx), axis=1)
tx_meld = tx_meld.drop(columns=['causa_uscita'])

# %%
plot_pie(tx_meld['transplant_done'], True)

# %%
tx_meld = tx_meld[(tx_meld['transplant_done'].isin([0, 1])) & (~pd.isna(tx_meld['MELD_base']))]

tx_meld.head(10)
# Out:
#     MELD_base  transplant_done
# 0         8.0                1
# 1        10.0                0
# 3        14.0                0
# 4        16.0                0
# 5        19.0                1
# 6        13.0                0
# 7        21.0                0
# 8        16.0                0
# 9        18.0                1
# 10       29.0                1

# %%
tx_meld['dummy'] = 0 # used only to plot
sns.violinplot(x='dummy', y='MELD_base', hue='transplant_done', data=tx_meld, split=True);
tx_meld.drop(columns=['dummy'], inplace=True)

# %%
corr, _ = pearsonr(tx_meld['MELD_base'], tx_meld['transplant_done'])
print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: 0.068

# %%
corr, _ = spearmanr(tx_meld['MELD_base'], tx_meld['transplant_done'])
print('Spearmans correlation: %.3f' % corr)
# Out:
# Spearmans correlation: 0.071

# %% [markdown]
# #### 2) Compare the ROC curve of the best estimator with respect to the ROC curve using only the MELD score for estimation

# %%
cls_extra = ExtraTreesClassifier(criterion = 'gini',
                                 max_depth = 22,
                                 bootstrap = False,
                                 max_features = None,
                                 min_samples_split = 2,
                                 random_state = seed)
cls_extra.fit(X_train, y_train);

# %%
# Using the best estimator
y_pred_proba = cls_extra.predict_proba(X_test)[:, 1]
fpr_estimator, tpr_estimator, _ = roc_curve(y_test, y_pred_proba)

# Using MELD score
fpr_meld, tpr_meld, _ = roc_curve(y_test, X_test['MELD_base'], pos_label=1)

# %%
# calculating Area Under Curve (AUC)
auc_estimator = auc(fpr_estimator, tpr_estimator)
auc_meld = auc(fpr_meld, tpr_meld)

# %%
plt.plot(fpr_estimator, tpr_estimator, label='ExtraTrees estimator (AUC = {:.2f})'.format(auc_estimator))
plt.plot(fpr_meld, tpr_meld, label='MELD score (AUC = {:.2f})'.format(auc_meld))
plt.legend()
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.show()

# %% [markdown]
# ## Neural Networks approaches

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import LogisticRegression

import tensorflow as tf

# %% [markdown]
# Standardization

# %%
X_train_original = X_train.copy(deep=True)
X_test_original = X_test.copy(deep=True)

# %%
X_train = X_train_original.copy(deep=True)
X_test = X_test_original.copy(deep=True)

# %%
scaler = StandardScaler()
scaler.fit(X_train)

X_train_scaled_array = scaler.transform(X_train)
X_test_scaled_array = scaler.transform(X_test)

X_train = pd.DataFrame(X_train_scaled_array, index=X_train.index, columns=X_train.columns)
X_test = pd.DataFrame(X_test_scaled_array, index=X_test.index, columns=X_test.columns)

# %%
'''
scaler = MinMaxScaler()
scaler.fit(X_train)

X_train_scaled_array = scaler.transform(X_train)
X_test_scaled_array = scaler.transform(X_test)

X_train = pd.DataFrame(X_train_scaled_array, index=X_train.index, columns=X_train.columns)
X_test = pd.DataFrame(X_test_scaled_array, index=X_test.index, columns=X_test.columns)
'''
# Out:
# '\nscaler = MinMaxScaler()\nscaler.fit(X_train)\n\nX_train_scaled_array = scaler.transform(X_train)\nX_test_scaled_array = scaler.transform(X_test)\n\nX_train = pd.DataFrame(X_train_scaled_array, index=X_train.index, columns=X_train.columns)\nX_test = pd.DataFrame(X_test_scaled_array, index=X_test.index, columns=X_test.columns)\n'

# %% [markdown]
# ### Logistic Regression

# %%
param_grid = [{
    'penalty': ['l2', 'none'],
    'tol': [1e-3, 1e-4, 1e-5],
    'C': [0.5, 1.0, 1.5],
    'solver': ['lbfgs']
}]

classifier = LogisticRegression(class_weight={1: 1, 0: 1}, random_state=seed)

grid_search = GridSearchCV(classifier, param_grid, scoring=custom_score, cv=5, n_jobs=4)

grid_search.fit(X_train, y_train)

print(grid_search.best_score_)
print(grid_search.best_params_)
# Out:
# -334.6
# {'C': 0.5, 'penalty': 'l2', 'solver': 'lbfgs', 'tol': 0.001}

# %%
logreg = LogisticRegression(penalty = 'l2',
                            tol = 1e-3,
                            C = 0.5,
                            solver = 'lbfgs',
                            random_state = seed)

logreg.fit(X_train, y_train)

print('Logistic Regression cost (train): {}'.format(-custom_score(logreg, X_train, y_train)))
print('Logistic Regression cost (test): {}'.format(-custom_score(logreg, X_test, y_test)))
# Out:
# Logistic Regression cost (train): 1599
# Logistic Regression cost (test): 409

# %%
plot_confusion_matrix(logreg, X_test, y_test);

# %%
X_train.columns
# Out:
# Index(['pers_sesso', 'pers_eta_ingresso_in_lista', 'tot_tx_organo',
#        'tx_fegato_corrente', 'tx_cuore', 'tx_intestino', 'tx_pancreas',
#        'tx_rene', 'ric_HBsAg', 'ric_DELTA', 'ric_HCV', 'ric_HCV_RNA',
#        'ric_HIV', 'Peso', 'Altezza', 'BMI', 'chirurgia_addom',
#        'trombosi_portale', 'TIPS', 'ric_diabete', 'HCC', 'MELD_base',
#        'dialisi_ultimi_15gg', 'UNOS', 'CHILD', 'ric_ospedalizzazione_al_tx',
#        'organo_trapiantato', 'ischemia_fredda', 'ric_ripresa_funzionale',
#        'donatore_eta', 'donatore_sesso', 'donatore_peso', 'donatore_altezza',
#        'donatore_BMI', 'donatore_cardiopatia', 'donatore_ipertensione',
#        'donatore_diabete', 'donatore_diabete_insulinodipendente',
#        'donatore_dislipidemie', 'donatore_sodio_avg', 'donatore_AST_avg',
#        'donatore_ALT_avg', 'donatore_bilirubinaTot_avg',
#        'donatore_fosfatasi_avg', 'donatore_gammaGT_avg',
#        'donatore_arresto_cardiaco', 'donatore_hcv', 'donatore_HBsAg',
#        'donatore_HBsAb', 'donatore_antiCoreTot', 'donatore_hbv_dna',
#        'donatore_hcv_rna', 'donatore_steatosiMacro',
#        'donatore_livelloRischioPreLT', 'diagnosi_epatocarcinoma',
#        'diagnosi_cirrosi_hcv', 'diagnosi_cirrosi_laennec',
#        'diagnosi_ritrapianto_rigetto', 'diagnosi_altro',
#        'donatore_caus_decesso_emorragia', 'donatore_caus_decesso_trauma',
#        'donatore_caus_decesso_encefalopatia', 'donatore_caus_decesso_ictus',
#        'donatore_caus_decesso_altro'],
#       dtype='object')

# %%
logreg.coef_
# Out:
# array([[ 0.04779792, -0.28567196, -0.11001302, -0.07777038, -0.00052949,
#         -0.1337415 , -0.06263445, -0.00718382, -0.00296652,  0.26578845,
#         -0.0153515 , -0.21109055, -0.08712174,  0.29821398, -0.23852489,
#         -0.2225218 , -0.0171757 , -0.09494381, -0.0014841 ,  0.01427058,
#          0.12459428, -0.26140186, -0.16615734, -0.03779764, -0.01609408,
#         -0.15270647, -0.10862238, -0.07176449,  0.21128922, -0.14446451,
#         -0.02038505, -0.04955042,  0.10627256, -0.02964842, -0.06415555,
#          0.05262577, -0.0893446 , -0.14258674,  0.00376664, -0.05994578,
#         -0.10024831, -0.09071533, -0.16907894,  0.13798939, -0.22625422,
#         -0.06828073, -0.10331668, -0.09163922,  0.12312888, -0.45129808,
#          0.23253051, -0.05511904,  0.16738437,  0.16979272, -0.14073695,
#          0.00834025,  0.14054759, -0.05107931,  0.06861434, -0.04716684,
#          0.04740877,  0.04970997,  0.01137679, -0.04930002]])

# %% [markdown]
# ### Neural Network

# %%
custom_score_tf = make_scorer(get_cost_tf, greater_is_better=False, cost_matrix=cost_matrix)

# %%
nn = NeuralNetwork(cost_matrix, epochs=10, hidden_dim=[32, 10], class_weight={0: 8, 1: 1})

history = nn.fit(X_train, y_train)
# Out:
# Epoch 1/10
# 36/36 [==============================] - 1s 29ms/step - loss: 1.6491 - cost: 957.0000
# Epoch 2/10
# 36/36 [==============================] - 1s 30ms/step - loss: 1.4694 - cost: 927.0000
# Epoch 3/10
# 36/36 [==============================] - 1s 30ms/step - loss: 1.4056 - cost: 863.0000
# Epoch 4/10
# 36/36 [==============================] - 1s 30ms/step - loss: 1.3624 - cost: 809.0000
# Epoch 5/10
# 36/36 [==============================] - 1s 30ms/step - loss: 1.3284 - cost: 810.0000
# Epoch 6/10
# 36/36 [==============================] - 1s 32ms/step - loss: 1.2980 - cost: 767.0000
# Epoch 7/10
# 36/36 [==============================] - 1s 30ms/step - loss: 1.2715 - cost: 718.0000
# Epoch 8/10
# 36/36 [==============================] - 1s 30ms/step - loss: 1.2443 - cost: 703.0000
# Epoch 9/10
# 36/36 [==============================] - 1s 30ms/step - loss: 1.2189 - cost: 690.0000
# Epoch 10/10
# 36/36 [==============================] - 1s 30ms/step - loss: 1.1998 - cost: 661.0000

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_cost = history.history['cost']
val_cost = history.history['val_cost']

ep = range(1, len(train_loss)+1)

fig, axis = plt.subplots(2)
fig.set_figheight(10)
fig.set_figwidth(12)

axis[0].plot(ep, train_loss, label='Train Loss')
axis[0].plot(ep, val_loss, label='Val Loss')
axis[1].plot(ep, train_cost, label='Train Cost')
axis[1].plot(ep, val_cost, label='Val Cost')

plt.xlabel('Epochs')
axis[0].set_ylabel('Loss')
axis[1].set_ylabel('Cost')
axis[0].legend()
axis[1].legend();
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-194-9dbf218f51e7> in <module>
#       1 train_loss = history.history['loss']
# ----> 2 val_loss = history.history['val_loss']
#       3 train_cost = history.history['cost']
#       4 val_cost = history.history['val_cost']
#       5
#
# KeyError: 'val_loss'

# %%
print('Neural Network cost (train): {}'.format(-custom_score_tf(nn, X_train, y_train)))
print('Neural Network cost (test): {}'.format(-custom_score_tf(nn, X_test, y_test)))
# Out:
# Neural Network cost (train): 615.0
# Neural Network cost (test): 234.0

# %%
threshold = 0.5
y_pred = (nn.predict(X_test) > threshold).astype('float')
cm = confusion_matrix(y_test, y_pred)

disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp = disp.plot()
plt.show()

# %%
param_grid = [{
    'epochs': [10, 20, 30, 40],
    'class_weight': [{0: 1, 1: 1}],
    'hidden_dim': [[32, 10], [12, 6]]
}]

classifier = NeuralNetwork(cost_matrix)

grid_search = GridSearchCV(classifier, param_grid, scoring=custom_score_tf, cv=5, n_jobs=1)

history = grid_search.fit(X_train, y_train)

print(grid_search.best_score_)
print(grid_search.best_params_)
# Out:
# WARNING:tensorflow:From /home/tree/.local/lib/python3.8/site-packages/tensorflow/python/ops/array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/10
# 29/29 [==============================] - 1s 30ms/step - loss: 0.8404 - cost: 832.0000
# Epoch 2/10
# 29/29 [==============================] - 1s 30ms/step - loss: 0.6711 - cost: 1138.0000
# Epoch 3/10
# 29/29 [==============================] - 1s 30ms/step - loss: 0.5977 - cost: 1306.0000
# Epoch 4/10
# 29/29 [==============================] - 1s 30ms/step - loss: 0.5452 - cost: 1354.0000
# Epoch 5/10
# 29/29 [==============================] - 1s 29ms/step - loss: 0.5069 - cost: 1357.0000
# Epoch 6/10
# 29/29 [==============================] - 1s 29ms/step - loss: 0.4803 - cost: 1371.0000
# Epoch 7/10
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4618 - cost: 1349.0000
# Epoch 8/10
# 29/29 [==============================] - 1s 29ms/step - loss: 0.4476 - cost: 1284.0000
# Epoch 9/10
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4350 - cost: 1244.0000
# Epoch 10/10
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4245 - cost: 1228.0000
# Epoch 1/10
# 29/29 [==============================] - 1s 31ms/step - loss: 1.1080 - cost: 766.0000
# Epoch 2/10
# 29/29 [==============================] - 1s 31ms/step - loss: 0.7321 - cost: 991.0000
# Epoch 3/10
# 29/29 [==============================] - 1s 31ms/step - loss: 0.6128 - cost: 1251.0000
# Epoch 4/10
# 29/29 [==============================] - 1s 31ms/step - loss: 0.5467 - cost: 1361.0000
# Epoch 5/10
# 29/29 [==============================] - 1s 30ms/step - loss: 0.5070 - cost: 1410.0000
# Epoch 6/10
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4803 - cost: 1408.0000
# Epoch 7/10
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4594 - cost: 1368.0000
# Epoch 8/10
# 29/29 [==============================] - 1s 32ms/step - loss: 0.4431 - cost: 1320.0000
# Epoch 9/10
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4287 - cost: 1259.0000
# Epoch 10/10
# 29/29 [==============================] - 1s 37ms/step - loss: 0.4162 - cost: 1237.0000
# Epoch 1/10
# 29/29 [==============================] - 1s 31ms/step - loss: 1.1155 - cost: 822.0000
# Epoch 2/10
# 29/29 [==============================] - 1s 34ms/step - loss: 0.7318 - cost: 983.0000
# Epoch 3/10
# 29/29 [==============================] - 1s 31ms/step - loss: 0.6126 - cost: 1230.0000
# Epoch 4/10
# 29/29 [==============================] - 1s 42ms/step - loss: 0.5508 - cost: 1376.0000
# Epoch 5/10
# 29/29 [==============================] - 1s 37ms/step - loss: 0.5075 - cost: 1420.0000
# Epoch 6/10
# 29/29 [==============================] - 1s 36ms/step - loss: 0.4802 - cost: 1433.0000
# Epoch 7/10
# 29/29 [==============================] - 1s 34ms/step - loss: 0.4613 - cost: 1408.0000
# Epoch 8/10
# 29/29 [==============================] - 1s 34ms/step - loss: 0.4445 - cost: 1330.0000
# Epoch 9/10
# 29/29 [==============================] - 1s 38ms/step - loss: 0.4316 - cost: 1282.0000
# Epoch 10/10
# 29/29 [==============================] - 1s 35ms/step - loss: 0.4198 - cost: 1244.0000
# Epoch 1/10
# 29/29 [==============================] - 1s 31ms/step - loss: 1.1061 - cost: 795.0000
# Epoch 2/10
# 29/29 [==============================] - 1s 31ms/step - loss: 0.7374 - cost: 980.0000
# Epoch 3/10
# 29/29 [==============================] - 1s 39ms/step - loss: 0.6211 - cost: 1245.0000
# Epoch 4/10
# 29/29 [==============================] - 1s 31ms/step - loss: 0.5585 - cost: 1358.0000
# Epoch 5/10
# 29/29 [==============================] - 1s 31ms/step - loss: 0.5146 - cost: 1435.0000
# Epoch 6/10
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4865 - cost: 1425.0000
# Epoch 7/10
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4666 - cost: 1393.0000
# Epoch 8/10
# 29/29 [==============================] - 1s 33ms/step - loss: 0.4500 - cost: 1337.0000
# Epoch 9/10
# 29/29 [==============================] - 1s 33ms/step - loss: 0.4363 - cost: 1314.0000
# Epoch 10/10
# 29/29 [==============================] - 1s 37ms/step - loss: 0.4256 - cost: 1268.0000
# Epoch 1/10
# 29/29 [==============================] - 1s 36ms/step - loss: 1.1171 - cost: 830.0000
# Epoch 2/10
# 29/29 [==============================] - 1s 35ms/step - loss: 0.7423 - cost: 1063.0000
# Epoch 3/10
# 29/29 [==============================] - 1s 33ms/step - loss: 0.6240 - cost: 1308.0000
# Epoch 4/10
# 29/29 [==============================] - 1s 32ms/step - loss: 0.5603 - cost: 1368.0000
# Epoch 5/10
# 29/29 [==============================] - 1s 33ms/step - loss: 0.5189 - cost: 1412.0000
# Epoch 6/10
# 29/29 [==============================] - 1s 32ms/step - loss: 0.4919 - cost: 1409.0000
# Epoch 7/10
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4739 - cost: 1408.0000
# Epoch 8/10
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4590 - cost: 1369.0000
# Epoch 9/10
# 29/29 [==============================] - 1s 32ms/step - loss: 0.4464 - cost: 1321.0000
# Epoch 10/10
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4351 - cost: 1290.0000
# Epoch 1/10
# 29/29 [==============================] - 1s 31ms/step - loss: 1.1096 - cost: 759.0000
# Epoch 2/10
# 29/29 [==============================] - 1s 31ms/step - loss: 0.7347 - cost: 989.0000
# Epoch 3/10
# 29/29 [==============================] - 1s 30ms/step - loss: 0.6166 - cost: 1217.0000
# Epoch 4/10
# 29/29 [==============================] - 1s 31ms/step - loss: 0.5538 - cost: 1351.0000
# Epoch 5/10
# 29/29 [==============================] - 1s 31ms/step - loss: 0.5146 - cost: 1396.0000
# Epoch 6/10
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4886 - cost: 1433.0000
# Epoch 7/10
# 29/29 [==============================] - 1s 32ms/step - loss: 0.4681 - cost: 1401.0000
# Epoch 8/10
# 29/29 [==============================] - 1s 33ms/step - loss: 0.4513 - cost: 1363.0000
# Epoch 9/10
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4363 - cost: 1308.0000
# Epoch 10/10
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4247 - cost: 1260.0000
# Epoch 1/10
# 29/29 [==============================] - 1s 31ms/step - loss: 1.1080 - cost: 766.0000
# Epoch 2/10
# 29/29 [==============================] - 1s 30ms/step - loss: 0.7321 - cost: 991.0000
# Epoch 3/10
# 29/29 [==============================] - 1s 30ms/step - loss: 0.6128 - cost: 1251.0000
# Epoch 4/10
# 29/29 [==============================] - 1s 31ms/step - loss: 0.5467 - cost: 1361.0000
# Epoch 5/10
# 29/29 [==============================] - 1s 31ms/step - loss: 0.5070 - cost: 1410.0000
# Epoch 6/10
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4803 - cost: 1408.0000
# Epoch 7/10
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4594 - cost: 1368.0000
# Epoch 8/10
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4431 - cost: 1320.0000
# Epoch 9/10
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4287 - cost: 1259.0000
# Epoch 10/10
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4162 - cost: 1237.0000
# Epoch 1/10
# 29/29 [==============================] - 1s 31ms/step - loss: 1.1155 - cost: 822.0000
# Epoch 2/10
# 29/29 [==============================] - 1s 30ms/step - loss: 0.7318 - cost: 983.0000
# Epoch 3/10
# 29/29 [==============================] - 1s 30ms/step - loss: 0.6126 - cost: 1230.0000
# Epoch 4/10
# 29/29 [==============================] - 1s 31ms/step - loss: 0.5508 - cost: 1376.0000
# Epoch 5/10
# 29/29 [==============================] - 1s 31ms/step - loss: 0.5075 - cost: 1420.0000
# Epoch 6/10
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4802 - cost: 1433.0000
# Epoch 7/10
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4613 - cost: 1408.0000
# Epoch 8/10
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4445 - cost: 1330.0000
# Epoch 9/10
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4316 - cost: 1282.0000
# Epoch 10/10
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4198 - cost: 1244.0000
# Epoch 1/10
# 29/29 [==============================] - 1s 31ms/step - loss: 1.1061 - cost: 795.0000
# Epoch 2/10
# 29/29 [==============================] - 1s 31ms/step - loss: 0.7374 - cost: 980.0000
# Epoch 3/10
# 29/29 [==============================] - 1s 30ms/step - loss: 0.6211 - cost: 1245.0000
# Epoch 4/10
# 29/29 [==============================] - 1s 31ms/step - loss: 0.5585 - cost: 1358.0000
# Epoch 5/10
# 29/29 [==============================] - 1s 31ms/step - loss: 0.5146 - cost: 1435.0000
# Epoch 6/10
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4865 - cost: 1425.0000
# Epoch 7/10
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4666 - cost: 1393.0000
# Epoch 8/10
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4500 - cost: 1337.0000
# Epoch 9/10
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4363 - cost: 1314.0000
# Epoch 10/10
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4256 - cost: 1268.0000
# Epoch 1/10
# 29/29 [==============================] - 1s 35ms/step - loss: 1.1171 - cost: 830.0000
# Epoch 2/10
# 29/29 [==============================] - 1s 30ms/step - loss: 0.7423 - cost: 1063.0000
# Epoch 3/10
# 29/29 [==============================] - 1s 31ms/step - loss: 0.6240 - cost: 1308.0000
# Epoch 4/10
# 29/29 [==============================] - 1s 31ms/step - loss: 0.5603 - cost: 1368.0000
# Epoch 5/10
# 29/29 [==============================] - 1s 30ms/step - loss: 0.5189 - cost: 1412.0000
# Epoch 6/10
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4919 - cost: 1409.0000
# Epoch 7/10
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4739 - cost: 1408.0000
# Epoch 8/10
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4590 - cost: 1369.0000
# Epoch 9/10
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4464 - cost: 1321.0000
# Epoch 10/10
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4351 - cost: 1290.0000
# Epoch 1/20
# 29/29 [==============================] - 1s 31ms/step - loss: 1.1096 - cost: 759.0000
# Epoch 2/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.7347 - cost: 989.0000
# Epoch 3/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.6166 - cost: 1217.0000
# Epoch 4/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.5538 - cost: 1351.0000
# Epoch 5/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.5146 - cost: 1396.0000
# Epoch 6/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4886 - cost: 1433.0000
# Epoch 7/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4681 - cost: 1401.0000
# Epoch 8/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4513 - cost: 1363.0000
# Epoch 9/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4363 - cost: 1308.0000
# Epoch 10/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4247 - cost: 1260.0000
# Epoch 11/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4142 - cost: 1218.0000
# Epoch 12/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4060 - cost: 1197.0000
# Epoch 13/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3973 - cost: 1111.0000
# Epoch 14/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3892 - cost: 1073.0000
# Epoch 15/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3812 - cost: 1047.0000
# Epoch 16/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3727 - cost: 1023.0000
# Epoch 17/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3650 - cost: 1014.0000
# Epoch 18/20
# 29/29 [==============================] - 1s 34ms/step - loss: 0.3570 - cost: 944.0000
# Epoch 19/20
# 29/29 [==============================] - 1s 28ms/step - loss: 0.3490 - cost: 944.0000
# Epoch 20/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.3416 - cost: 937.0000
# Epoch 1/20
# 29/29 [==============================] - 1s 27ms/step - loss: 1.1080 - cost: 766.0000
# Epoch 2/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.7321 - cost: 991.0000
# Epoch 3/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6128 - cost: 1251.0000
# Epoch 4/20
# 29/29 [==============================] - 1s 28ms/step - loss: 0.5467 - cost: 1361.0000
# Epoch 5/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.5070 - cost: 1410.0000
# Epoch 6/20
# 29/29 [==============================] - 1s 28ms/step - loss: 0.4803 - cost: 1408.0000
# Epoch 7/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.4594 - cost: 1368.0000
# Epoch 8/20
# 29/29 [==============================] - 1s 28ms/step - loss: 0.4431 - cost: 1320.0000
# Epoch 9/20
# 29/29 [==============================] - 1s 28ms/step - loss: 0.4287 - cost: 1259.0000
# Epoch 10/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.4162 - cost: 1237.0000
# Epoch 11/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.4060 - cost: 1159.0000
# Epoch 12/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.3971 - cost: 1158.0000
# Epoch 13/20
# 29/29 [==============================] - 1s 28ms/step - loss: 0.3878 - cost: 1071.0000
# Epoch 14/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.3793 - cost: 1047.0000
# Epoch 15/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.3715 - cost: 1062.0000
# Epoch 16/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.3626 - cost: 1021.0000
# Epoch 17/20
# 29/29 [==============================] - 1s 28ms/step - loss: 0.3544 - cost: 999.0000
# Epoch 18/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.3471 - cost: 950.0000
# Epoch 19/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.3392 - cost: 942.0000
# Epoch 20/20
# 29/29 [==============================] - 1s 28ms/step - loss: 0.3317 - cost: 902.0000
# Epoch 1/20
# 29/29 [==============================] - 1s 27ms/step - loss: 1.1155 - cost: 822.0000
# Epoch 2/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.7318 - cost: 983.0000
# Epoch 3/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6126 - cost: 1230.0000
# Epoch 4/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.5508 - cost: 1376.0000
# Epoch 5/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.5075 - cost: 1420.0000
# Epoch 6/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.4802 - cost: 1433.0000
# Epoch 7/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.4613 - cost: 1408.0000
# Epoch 8/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.4445 - cost: 1330.0000
# Epoch 9/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.4316 - cost: 1282.0000
# Epoch 10/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.4198 - cost: 1244.0000
# Epoch 11/20
# 29/29 [==============================] - 1s 28ms/step - loss: 0.4091 - cost: 1228.0000
# Epoch 12/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.3991 - cost: 1189.0000
# Epoch 13/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.3894 - cost: 1182.0000
# Epoch 14/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.3816 - cost: 1142.0000
# Epoch 15/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.3738 - cost: 1111.0000
# Epoch 16/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.3659 - cost: 1111.0000
# Epoch 17/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.3585 - cost: 1079.0000
# Epoch 18/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3512 - cost: 1063.0000
# Epoch 19/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.3434 - cost: 1032.0000
# Epoch 20/20
# 29/29 [==============================] - 1s 28ms/step - loss: 0.3371 - cost: 1030.0000
# Epoch 1/20
# 29/29 [==============================] - 1s 27ms/step - loss: 1.1061 - cost: 795.0000
# Epoch 2/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.7374 - cost: 980.0000
# Epoch 3/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6211 - cost: 1245.0000
# Epoch 4/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.5585 - cost: 1358.0000
# Epoch 5/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.5146 - cost: 1435.0000
# Epoch 6/20
# 29/29 [==============================] - 1s 28ms/step - loss: 0.4865 - cost: 1425.0000
# Epoch 7/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.4666 - cost: 1393.0000
# Epoch 8/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.4500 - cost: 1337.0000
# Epoch 9/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.4363 - cost: 1314.0000
# Epoch 10/20
# 29/29 [==============================] - 1s 28ms/step - loss: 0.4256 - cost: 1268.0000
# Epoch 11/20
# 29/29 [==============================] - 1s 28ms/step - loss: 0.4155 - cost: 1250.0000
# Epoch 12/20
# 29/29 [==============================] - 1s 28ms/step - loss: 0.4065 - cost: 1222.0000
# Epoch 13/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.3972 - cost: 1189.0000
# Epoch 14/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.3881 - cost: 1149.0000
# Epoch 15/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.3803 - cost: 1118.0000
# Epoch 16/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.3719 - cost: 1102.0000
# Epoch 17/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.3640 - cost: 1077.0000
# Epoch 18/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.3568 - cost: 1037.0000
# Epoch 19/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.3491 - cost: 1010.0000
# Epoch 20/20
# 29/29 [==============================] - 1s 29ms/step - loss: 0.3409 - cost: 998.0000
# Epoch 1/20
# 29/29 [==============================] - 1s 28ms/step - loss: 1.1171 - cost: 830.0000
# Epoch 2/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.7423 - cost: 1063.0000
# Epoch 3/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6240 - cost: 1308.0000
# Epoch 4/20
# 29/29 [==============================] - 1s 28ms/step - loss: 0.5603 - cost: 1368.0000
# Epoch 5/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.5189 - cost: 1412.0000
# Epoch 6/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.4919 - cost: 1409.0000
# Epoch 7/20
# 29/29 [==============================] - 1s 27ms/step - loss: 0.4739 - cost: 1408.0000
# Epoch 8/20
# 29/29 [==============================] - 1s 34ms/step - loss: 0.4590 - cost: 1369.0000
# Epoch 9/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4464 - cost: 1321.0000
# Epoch 10/20
# 29/29 [==============================] - 1s 32ms/step - loss: 0.4351 - cost: 1290.0000
# Epoch 11/20
# 29/29 [==============================] - 1s 32ms/step - loss: 0.4245 - cost: 1268.0000
# Epoch 12/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4155 - cost: 1235.0000
# Epoch 13/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4054 - cost: 1236.0000
# Epoch 14/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3967 - cost: 1179.0000
# Epoch 15/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3882 - cost: 1164.0000
# Epoch 16/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3796 - cost: 1100.0000
# Epoch 17/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3715 - cost: 1059.0000
# Epoch 18/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3633 - cost: 1003.0000
# Epoch 19/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3560 - cost: 956.0000
# Epoch 20/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3479 - cost: 947.0000
# Epoch 1/20
# 29/29 [==============================] - 1s 32ms/step - loss: 1.1096 - cost: 759.0000
# Epoch 2/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.7347 - cost: 989.0000
# Epoch 3/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.6166 - cost: 1217.0000
# Epoch 4/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.5538 - cost: 1351.0000
# Epoch 5/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.5146 - cost: 1396.0000
# Epoch 6/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4886 - cost: 1433.0000
# Epoch 7/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4681 - cost: 1401.0000
# Epoch 8/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4513 - cost: 1363.0000
# Epoch 9/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4363 - cost: 1308.0000
# Epoch 10/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4247 - cost: 1260.0000
# Epoch 11/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4142 - cost: 1218.0000
# Epoch 12/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4060 - cost: 1197.0000
# Epoch 13/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3973 - cost: 1111.0000
# Epoch 14/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3892 - cost: 1073.0000
# Epoch 15/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3812 - cost: 1047.0000
# Epoch 16/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3727 - cost: 1023.0000
# Epoch 17/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3650 - cost: 1014.0000
# Epoch 18/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3570 - cost: 944.0000
# Epoch 19/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3490 - cost: 944.0000
# Epoch 20/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3416 - cost: 937.0000
# Epoch 1/20
# 29/29 [==============================] - 1s 31ms/step - loss: 1.1080 - cost: 766.0000
# Epoch 2/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.7321 - cost: 991.0000
# Epoch 3/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.6128 - cost: 1251.0000
# Epoch 4/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.5467 - cost: 1361.0000
# Epoch 5/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.5070 - cost: 1410.0000
# Epoch 6/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4803 - cost: 1408.0000
# Epoch 7/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4594 - cost: 1368.0000
# Epoch 8/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4431 - cost: 1320.0000
# Epoch 9/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4287 - cost: 1259.0000
# Epoch 10/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4162 - cost: 1237.0000
# Epoch 11/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4060 - cost: 1159.0000
# Epoch 12/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3971 - cost: 1158.0000
# Epoch 13/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3878 - cost: 1071.0000
# Epoch 14/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3793 - cost: 1047.0000
# Epoch 15/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3715 - cost: 1062.0000
# Epoch 16/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3626 - cost: 1021.0000
# Epoch 17/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3544 - cost: 999.0000
# Epoch 18/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3471 - cost: 950.0000
# Epoch 19/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3392 - cost: 942.0000
# Epoch 20/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3317 - cost: 902.0000
# Epoch 1/20
# 29/29 [==============================] - 1s 30ms/step - loss: 1.1155 - cost: 822.0000
# Epoch 2/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.7318 - cost: 983.0000
# Epoch 3/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.6126 - cost: 1230.0000
# Epoch 4/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.5508 - cost: 1376.0000
# Epoch 5/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.5075 - cost: 1420.0000
# Epoch 6/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4802 - cost: 1433.0000
# Epoch 7/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4613 - cost: 1408.0000
# Epoch 8/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4445 - cost: 1330.0000
# Epoch 9/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4316 - cost: 1282.0000
# Epoch 10/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4198 - cost: 1244.0000
# Epoch 11/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4091 - cost: 1228.0000
# Epoch 12/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3991 - cost: 1189.0000
# Epoch 13/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3894 - cost: 1182.0000
# Epoch 14/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3816 - cost: 1142.0000
# Epoch 15/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3738 - cost: 1111.0000
# Epoch 16/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3659 - cost: 1111.0000
# Epoch 17/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3585 - cost: 1079.0000
# Epoch 18/20
# 29/29 [==============================] - 1s 32ms/step - loss: 0.3512 - cost: 1063.0000
# Epoch 19/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3434 - cost: 1032.0000
# Epoch 20/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3371 - cost: 1030.0000
# Epoch 1/20
# 29/29 [==============================] - 1s 30ms/step - loss: 1.1061 - cost: 795.0000
# Epoch 2/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.7374 - cost: 980.0000
# Epoch 3/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.6211 - cost: 1245.0000
# Epoch 4/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.5585 - cost: 1358.0000
# Epoch 5/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.5146 - cost: 1435.0000
# Epoch 6/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4865 - cost: 1425.0000
# Epoch 7/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4666 - cost: 1393.0000
# Epoch 8/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4500 - cost: 1337.0000
# Epoch 9/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4363 - cost: 1314.0000
# Epoch 10/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4256 - cost: 1268.0000
# Epoch 11/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4155 - cost: 1250.0000
# Epoch 12/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4065 - cost: 1222.0000
# Epoch 13/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3972 - cost: 1189.0000
# Epoch 14/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3881 - cost: 1149.0000
# Epoch 15/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3803 - cost: 1118.0000
# Epoch 16/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3719 - cost: 1102.0000
# Epoch 17/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3640 - cost: 1077.0000
# Epoch 18/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3568 - cost: 1037.0000
# Epoch 19/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3491 - cost: 1010.0000
# Epoch 20/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3409 - cost: 998.0000
# Epoch 1/20
# 29/29 [==============================] - 1s 30ms/step - loss: 1.1171 - cost: 830.0000
# Epoch 2/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.7423 - cost: 1063.0000
# Epoch 3/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.6240 - cost: 1308.0000
# Epoch 4/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.5603 - cost: 1368.0000
# Epoch 5/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.5189 - cost: 1412.0000
# Epoch 6/20
# 29/29 [==============================] - 1s 32ms/step - loss: 0.4919 - cost: 1409.0000
# Epoch 7/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4739 - cost: 1408.0000
# Epoch 8/20
# 29/29 [==============================] - 1s 37ms/step - loss: 0.4590 - cost: 1369.0000
# Epoch 9/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4464 - cost: 1321.0000
# Epoch 10/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4351 - cost: 1290.0000
# Epoch 11/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4245 - cost: 1268.0000
# Epoch 12/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4155 - cost: 1235.0000
# Epoch 13/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4054 - cost: 1236.0000
# Epoch 14/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3967 - cost: 1179.0000
# Epoch 15/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3882 - cost: 1164.0000
# Epoch 16/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3796 - cost: 1100.0000
# Epoch 17/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3715 - cost: 1059.0000
# Epoch 18/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3633 - cost: 1003.0000
# Epoch 19/20
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3560 - cost: 956.0000
# Epoch 20/20
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3479 - cost: 947.0000
# Epoch 1/30
# 29/29 [==============================] - 1s 30ms/step - loss: 1.1096 - cost: 759.0000
# Epoch 2/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.7347 - cost: 989.0000
# Epoch 3/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.6166 - cost: 1217.0000
# Epoch 4/30
# 29/29 [==============================] - 1s 32ms/step - loss: 0.5538 - cost: 1351.0000
# Epoch 5/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.5146 - cost: 1396.0000
# Epoch 6/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4886 - cost: 1433.0000
# Epoch 7/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4681 - cost: 1401.0000
# Epoch 8/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4513 - cost: 1363.0000
# Epoch 9/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4363 - cost: 1308.0000
# Epoch 10/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4247 - cost: 1260.0000
# Epoch 11/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4142 - cost: 1218.0000
# Epoch 12/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4060 - cost: 1197.0000
# Epoch 13/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3973 - cost: 1111.0000
# Epoch 14/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3892 - cost: 1073.0000
# Epoch 15/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3812 - cost: 1047.0000
# Epoch 16/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3727 - cost: 1023.0000
# Epoch 17/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3650 - cost: 1014.0000
# Epoch 18/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3570 - cost: 944.0000
# Epoch 19/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3490 - cost: 944.0000
# Epoch 20/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3416 - cost: 937.0000
# Epoch 21/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3338 - cost: 912.0000
# Epoch 22/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3255 - cost: 887.0000
# Epoch 23/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3182 - cost: 886.0000
# Epoch 24/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3105 - cost: 879.0000
# Epoch 25/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3024 - cost: 840.0000
# Epoch 26/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.2945 - cost: 824.0000
# Epoch 27/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2864 - cost: 793.0000
# Epoch 28/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2772 - cost: 754.0000
# Epoch 29/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.2696 - cost: 721.0000
# Epoch 30/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.2613 - cost: 697.0000
# Epoch 1/30
# 29/29 [==============================] - 1s 31ms/step - loss: 1.1080 - cost: 766.0000
# Epoch 2/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.7321 - cost: 991.0000
# Epoch 3/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.6128 - cost: 1251.0000
# Epoch 4/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.5467 - cost: 1361.0000
# Epoch 5/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.5070 - cost: 1410.0000
# Epoch 6/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4803 - cost: 1408.0000
# Epoch 7/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4594 - cost: 1368.0000
# Epoch 8/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4431 - cost: 1320.0000
# Epoch 9/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4287 - cost: 1259.0000
# Epoch 10/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4162 - cost: 1237.0000
# Epoch 11/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4060 - cost: 1159.0000
# Epoch 12/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3971 - cost: 1158.0000
# Epoch 13/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3878 - cost: 1071.0000
# Epoch 14/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3793 - cost: 1047.0000
# Epoch 15/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3715 - cost: 1062.0000
# Epoch 16/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3626 - cost: 1021.0000
# Epoch 17/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3544 - cost: 999.0000
# Epoch 18/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3471 - cost: 950.0000
# Epoch 19/30
# 29/29 [==============================] - 1s 32ms/step - loss: 0.3392 - cost: 942.0000
# Epoch 20/30
# 29/29 [==============================] - 1s 35ms/step - loss: 0.3317 - cost: 902.0000
# Epoch 21/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3241 - cost: 863.0000
# Epoch 22/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3147 - cost: 870.0000
# Epoch 23/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3064 - cost: 823.0000
# Epoch 24/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.2988 - cost: 814.0000
# Epoch 25/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2903 - cost: 774.0000
# Epoch 26/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.2829 - cost: 774.0000
# Epoch 27/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.2742 - cost: 757.0000
# Epoch 28/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2665 - cost: 725.0000
# Epoch 29/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.2581 - cost: 717.0000
# Epoch 30/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.2504 - cost: 685.0000
# Epoch 1/30
# 29/29 [==============================] - 1s 30ms/step - loss: 1.1155 - cost: 822.0000
# Epoch 2/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.7318 - cost: 983.0000
# Epoch 3/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.6126 - cost: 1230.0000
# Epoch 4/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.5508 - cost: 1376.0000
# Epoch 5/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.5075 - cost: 1420.0000
# Epoch 6/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4802 - cost: 1433.0000
# Epoch 7/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4613 - cost: 1408.0000
# Epoch 8/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4445 - cost: 1330.0000
# Epoch 9/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4316 - cost: 1282.00000s - loss: 0.3939
# Epoch 10/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4198 - cost: 1244.0000
# Epoch 11/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4091 - cost: 1228.0000
# Epoch 12/30
# 29/29 [==============================] - 1s 32ms/step - loss: 0.3991 - cost: 1189.0000
# Epoch 13/30
# 29/29 [==============================] - 1s 37ms/step - loss: 0.3894 - cost: 1182.0000
# Epoch 14/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3816 - cost: 1142.0000
# Epoch 15/30
# 29/29 [==============================] - 1s 40ms/step - loss: 0.3738 - cost: 1111.0000
# Epoch 16/30
# 29/29 [==============================] - 1s 33ms/step - loss: 0.3659 - cost: 1111.0000
# Epoch 17/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3585 - cost: 1079.0000
# Epoch 18/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3512 - cost: 1063.0000
# Epoch 19/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3434 - cost: 1032.0000
# Epoch 20/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3371 - cost: 1030.0000
# Epoch 21/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3301 - cost: 938.0000
# Epoch 22/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3220 - cost: 904.0000
# Epoch 23/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3145 - cost: 847.0000
# Epoch 24/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3084 - cost: 879.0000
# Epoch 25/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2998 - cost: 807.0000
# Epoch 26/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2928 - cost: 789.0000
# Epoch 27/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2852 - cost: 767.0000
# Epoch 28/30
# 29/29 [==============================] - 1s 32ms/step - loss: 0.2771 - cost: 765.0000
# Epoch 29/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.2698 - cost: 764.0000
# Epoch 30/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2630 - cost: 716.0000
# Epoch 1/30
# 29/29 [==============================] - 1s 30ms/step - loss: 1.1061 - cost: 795.0000
# Epoch 2/30
# 29/29 [==============================] - 1s 32ms/step - loss: 0.7374 - cost: 980.0000
# Epoch 3/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.6211 - cost: 1245.0000
# Epoch 4/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.5585 - cost: 1358.0000
# Epoch 5/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.5146 - cost: 1435.0000
# Epoch 6/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4865 - cost: 1425.0000
# Epoch 7/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4666 - cost: 1393.0000
# Epoch 8/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4500 - cost: 1337.0000
# Epoch 9/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4363 - cost: 1314.0000
# Epoch 10/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4256 - cost: 1268.0000
# Epoch 11/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4155 - cost: 1250.0000
# Epoch 12/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4065 - cost: 1222.0000
# Epoch 13/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3972 - cost: 1189.0000
# Epoch 14/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3881 - cost: 1149.0000
# Epoch 15/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3803 - cost: 1118.0000
# Epoch 16/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3719 - cost: 1102.0000
# Epoch 17/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3640 - cost: 1077.0000
# Epoch 18/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3568 - cost: 1037.0000
# Epoch 19/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3491 - cost: 1010.0000
# Epoch 20/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3409 - cost: 998.0000
# Epoch 21/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3336 - cost: 934.0000
# Epoch 22/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3277 - cost: 910.0000
# Epoch 23/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3198 - cost: 870.0000
# Epoch 24/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3133 - cost: 830.0000
# Epoch 25/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3066 - cost: 815.0000
# Epoch 26/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.2989 - cost: 767.0000
# Epoch 27/30
# 29/29 [==============================] - 1s 35ms/step - loss: 0.2926 - cost: 743.0000
# Epoch 28/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2853 - cost: 759.0000
# Epoch 29/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2787 - cost: 735.0000
# Epoch 30/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.2717 - cost: 687.0000
# Epoch 1/30
# 29/29 [==============================] - 1s 30ms/step - loss: 1.1171 - cost: 830.0000
# Epoch 2/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.7423 - cost: 1063.0000
# Epoch 3/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.6240 - cost: 1308.0000
# Epoch 4/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.5603 - cost: 1368.0000
# Epoch 5/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.5189 - cost: 1412.0000
# Epoch 6/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4919 - cost: 1409.0000
# Epoch 7/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4739 - cost: 1408.00000s - loss: 0.4619 - cost:
# Epoch 8/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4590 - cost: 1369.0000
# Epoch 9/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4464 - cost: 1321.0000
# Epoch 10/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4351 - cost: 1290.0000
# Epoch 11/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4245 - cost: 1268.0000
# Epoch 12/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4155 - cost: 1235.0000
# Epoch 13/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4054 - cost: 1236.0000
# Epoch 14/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3967 - cost: 1179.0000
# Epoch 15/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3882 - cost: 1164.0000
# Epoch 16/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3796 - cost: 1100.0000
# Epoch 17/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3715 - cost: 1059.0000
# Epoch 18/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3633 - cost: 1003.0000
# Epoch 19/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3560 - cost: 956.0000
# Epoch 20/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3479 - cost: 947.0000
# Epoch 21/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3402 - cost: 918.0000
# Epoch 22/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3333 - cost: 916.0000
# Epoch 23/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3248 - cost: 886.0000
# Epoch 24/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3168 - cost: 869.0000
# Epoch 25/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3088 - cost: 821.0000
# Epoch 26/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3004 - cost: 782.0000
# Epoch 27/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2925 - cost: 790.0000
# Epoch 28/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.2837 - cost: 740.0000
# Epoch 29/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2748 - cost: 756.0000
# Epoch 30/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2671 - cost: 709.0000
# Epoch 1/30
# 29/29 [==============================] - 1s 31ms/step - loss: 1.1096 - cost: 759.0000
# Epoch 2/30
# 29/29 [==============================] - 1s 32ms/step - loss: 0.7347 - cost: 989.0000
# Epoch 3/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.6166 - cost: 1217.0000
# Epoch 4/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.5538 - cost: 1351.0000
# Epoch 5/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.5146 - cost: 1396.0000
# Epoch 6/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4886 - cost: 1433.0000
# Epoch 7/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4681 - cost: 1401.0000
# Epoch 8/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4513 - cost: 1363.0000
# Epoch 9/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4363 - cost: 1308.0000
# Epoch 10/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4247 - cost: 1260.0000
# Epoch 11/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4142 - cost: 1218.0000
# Epoch 12/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4060 - cost: 1197.0000
# Epoch 13/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3973 - cost: 1111.0000
# Epoch 14/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3892 - cost: 1073.0000
# Epoch 15/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3812 - cost: 1047.0000
# Epoch 16/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3727 - cost: 1023.0000
# Epoch 17/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3650 - cost: 1014.0000
# Epoch 18/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3570 - cost: 944.0000
# Epoch 19/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3490 - cost: 944.0000
# Epoch 20/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3416 - cost: 937.0000
# Epoch 21/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3338 - cost: 912.0000
# Epoch 22/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3255 - cost: 887.0000
# Epoch 23/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3182 - cost: 886.0000
# Epoch 24/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3105 - cost: 879.0000
# Epoch 25/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3024 - cost: 840.0000
# Epoch 26/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.2945 - cost: 824.0000
# Epoch 27/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2864 - cost: 793.0000
# Epoch 28/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2772 - cost: 754.0000
# Epoch 29/30
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2696 - cost: 721.0000
# Epoch 30/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.2613 - cost: 697.0000
# Epoch 1/30
# 29/29 [==============================] - 1s 30ms/step - loss: 1.1080 - cost: 766.0000
# Epoch 2/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.7321 - cost: 991.0000
# Epoch 3/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.6128 - cost: 1251.0000
# Epoch 4/30
# 29/29 [==============================] - 1s 31ms/step - loss: 0.5467 - cost: 1361.0000
# Epoch 5/30
# ...
# Epoch 29/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2581 - cost: 717.0000
# Epoch 30/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2504 - cost: 685.0000
# Epoch 31/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2425 - cost: 630.0000
# Epoch 32/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.2348 - cost: 645.0000
# Epoch 33/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.2263 - cost: 630.0000
# Epoch 34/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.2182 - cost: 598.0000
# Epoch 35/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.2102 - cost: 558.0000
# Epoch 36/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2019 - cost: 558.0000
# Epoch 37/40
# 29/29 [==============================] - 1s 33ms/step - loss: 0.1951 - cost: 478.0000
# Epoch 38/40
# 29/29 [==============================] - 1s 33ms/step - loss: 0.1877 - cost: 454.0000
# Epoch 39/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.1819 - cost: 437.0000
# Epoch 40/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.1742 - cost: 413.0000
# Epoch 1/40
# 29/29 [==============================] - 1s 30ms/step - loss: 1.1155 - cost: 822.0000
# Epoch 2/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.7318 - cost: 983.0000
# Epoch 3/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.6126 - cost: 1230.0000
# Epoch 4/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.5508 - cost: 1376.0000
# Epoch 5/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.5075 - cost: 1420.0000
# Epoch 6/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4802 - cost: 1433.0000
# Epoch 7/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4613 - cost: 1408.0000
# Epoch 8/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4445 - cost: 1330.0000
# Epoch 9/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4316 - cost: 1282.0000
# Epoch 10/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4198 - cost: 1244.0000
# Epoch 11/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4091 - cost: 1228.0000
# Epoch 12/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3991 - cost: 1189.0000
# Epoch 13/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3894 - cost: 1182.0000
# Epoch 14/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3816 - cost: 1142.0000
# Epoch 15/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3738 - cost: 1111.0000
# Epoch 16/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3659 - cost: 1111.0000
# Epoch 17/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3585 - cost: 1079.0000
# Epoch 18/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3512 - cost: 1063.0000
# Epoch 19/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3434 - cost: 1032.0000
# Epoch 20/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3371 - cost: 1030.0000
# Epoch 21/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3301 - cost: 938.0000
# Epoch 22/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3220 - cost: 904.0000
# Epoch 23/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3145 - cost: 847.0000
# Epoch 24/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3084 - cost: 879.0000
# Epoch 25/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2998 - cost: 807.0000
# Epoch 26/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.2928 - cost: 789.0000
# Epoch 27/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.2852 - cost: 767.0000
# Epoch 28/40
# 29/29 [==============================] - 1s 32ms/step - loss: 0.2771 - cost: 765.0000
# Epoch 29/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.2698 - cost: 764.0000
# Epoch 30/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2630 - cost: 716.0000
# Epoch 31/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2565 - cost: 644.0000
# Epoch 32/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.2479 - cost: 645.0000
# Epoch 33/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2406 - cost: 588.0000
# Epoch 34/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.2345 - cost: 588.0000
# Epoch 35/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2262 - cost: 532.0000
# Epoch 36/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2196 - cost: 491.0000
# Epoch 37/40
# 29/29 [==============================] - 1s 35ms/step - loss: 0.2129 - cost: 491.0000
# Epoch 38/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2063 - cost: 483.0000
# Epoch 39/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.1990 - cost: 436.0000
# Epoch 40/40
# 29/29 [==============================] - 1s 34ms/step - loss: 0.1922 - cost: 389.0000
# Epoch 1/40
# 29/29 [==============================] - 1s 32ms/step - loss: 1.1061 - cost: 795.0000
# Epoch 2/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.7374 - cost: 980.0000
# Epoch 3/40
# 29/29 [==============================] - 1s 32ms/step - loss: 0.6211 - cost: 1245.0000
# Epoch 4/40
# 29/29 [==============================] - 1s 32ms/step - loss: 0.5585 - cost: 1358.0000
# Epoch 5/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.5146 - cost: 1435.0000
# Epoch 6/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4865 - cost: 1425.0000
# Epoch 7/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4666 - cost: 1393.0000
# Epoch 8/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4500 - cost: 1337.0000
# Epoch 9/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.4363 - cost: 1314.0000
# Epoch 10/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4256 - cost: 1268.0000
# Epoch 11/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4155 - cost: 1250.0000
# Epoch 12/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4065 - cost: 1222.0000
# Epoch 13/40
# 29/29 [==============================] - 1s 37ms/step - loss: 0.3972 - cost: 1189.0000
# Epoch 14/40
# 29/29 [==============================] - 1s 32ms/step - loss: 0.3881 - cost: 1149.0000
# Epoch 15/40
# 29/29 [==============================] - 1s 40ms/step - loss: 0.3803 - cost: 1118.0000
# Epoch 16/40
# 29/29 [==============================] - 1s 40ms/step - loss: 0.3719 - cost: 1102.0000
# Epoch 17/40
# 29/29 [==============================] - 1s 32ms/step - loss: 0.3640 - cost: 1077.0000
# Epoch 18/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3568 - cost: 1037.0000
# Epoch 19/40
# 29/29 [==============================] - 1s 33ms/step - loss: 0.3491 - cost: 1010.0000
# Epoch 20/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3409 - cost: 998.0000
# Epoch 21/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3336 - cost: 934.0000
# Epoch 22/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3277 - cost: 910.0000
# Epoch 23/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3198 - cost: 870.0000
# Epoch 24/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.3133 - cost: 830.0000
# Epoch 25/40
# 29/29 [==============================] - 1s 32ms/step - loss: 0.3066 - cost: 815.0000
# Epoch 26/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2989 - cost: 767.0000
# Epoch 27/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2926 - cost: 743.0000
# Epoch 28/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.2853 - cost: 759.0000
# Epoch 29/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2787 - cost: 735.0000
# Epoch 30/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.2717 - cost: 687.0000
# Epoch 31/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2660 - cost: 640.0000
# Epoch 32/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2591 - cost: 654.0000
# Epoch 33/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2519 - cost: 632.0000
# Epoch 34/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2460 - cost: 630.0000
# Epoch 35/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2376 - cost: 596.0000
# Epoch 36/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2311 - cost: 542.0000
# Epoch 37/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2245 - cost: 541.0000
# Epoch 38/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2177 - cost: 509.0000
# Epoch 39/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.2100 - cost: 492.0000
# Epoch 40/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.2044 - cost: 428.0000
# Epoch 1/40
# 29/29 [==============================] - 1s 31ms/step - loss: 1.1171 - cost: 830.0000
# Epoch 2/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.7423 - cost: 1063.0000
# Epoch 3/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.6240 - cost: 1308.0000
# Epoch 4/40
# 29/29 [==============================] - 1s 41ms/step - loss: 0.5603 - cost: 1368.0000
# Epoch 5/40
# 29/29 [==============================] - 1s 37ms/step - loss: 0.5189 - cost: 1412.0000
# Epoch 6/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4919 - cost: 1409.0000
# Epoch 7/40
# 29/29 [==============================] - 1s 32ms/step - loss: 0.4739 - cost: 1408.0000
# Epoch 8/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4590 - cost: 1369.0000
# Epoch 9/40
# 29/29 [==============================] - 1s 32ms/step - loss: 0.4464 - cost: 1321.0000
# Epoch 10/40
# 29/29 [==============================] - 1s 33ms/step - loss: 0.4351 - cost: 1290.0000
# Epoch 11/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.4245 - cost: 1268.0000
# Epoch 12/40
# 29/29 [==============================] - 1s 33ms/step - loss: 0.4155 - cost: 1235.0000
# Epoch 13/40
# 29/29 [==============================] - 1s 33ms/step - loss: 0.4054 - cost: 1236.0000
# Epoch 14/40
# 29/29 [==============================] - 1s 27ms/step - loss: 0.3967 - cost: 1179.0000
# Epoch 15/40
# 29/29 [==============================] - 1s 28ms/step - loss: 0.3882 - cost: 1164.0000
# Epoch 16/40
# 29/29 [==============================] - 1s 28ms/step - loss: 0.3796 - cost: 1100.0000
# Epoch 17/40
# 29/29 [==============================] - 1s 34ms/step - loss: 0.3715 - cost: 1059.0000
# Epoch 18/40
# 29/29 [==============================] - 1s 32ms/step - loss: 0.3633 - cost: 1003.0000
# Epoch 19/40
# 29/29 [==============================] - 1s 32ms/step - loss: 0.3560 - cost: 956.0000
# Epoch 20/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3479 - cost: 947.0000
# Epoch 21/40
# 29/29 [==============================] - 1s 34ms/step - loss: 0.3402 - cost: 918.0000
# Epoch 22/40
# 29/29 [==============================] - 1s 32ms/step - loss: 0.3333 - cost: 916.0000
# Epoch 23/40
# 29/29 [==============================] - 1s 34ms/step - loss: 0.3248 - cost: 886.0000
# Epoch 24/40
# 29/29 [==============================] - 1s 36ms/step - loss: 0.3168 - cost: 869.0000
# Epoch 25/40
# 29/29 [==============================] - 1s 33ms/step - loss: 0.3088 - cost: 821.0000
# Epoch 26/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.3004 - cost: 782.0000
# Epoch 27/40
# 29/29 [==============================] - 1s 32ms/step - loss: 0.2925 - cost: 790.0000
# Epoch 28/40
# 29/29 [==============================] - 1s 37ms/step - loss: 0.2837 - cost: 740.0000
# Epoch 29/40
# 29/29 [==============================] - 1s 36ms/step - loss: 0.2748 - cost: 756.0000
# Epoch 30/40
# 29/29 [==============================] - 1s 28ms/step - loss: 0.2671 - cost: 709.0000
# Epoch 31/40
# 29/29 [==============================] - 1s 28ms/step - loss: 0.2603 - cost: 647.0000
# Epoch 32/40
# 29/29 [==============================] - 1s 29ms/step - loss: 0.2523 - cost: 678.0000
# Epoch 33/40
# 29/29 [==============================] - 1s 28ms/step - loss: 0.2442 - cost: 590.0000
# Epoch 34/40
# 29/29 [==============================] - 1s 28ms/step - loss: 0.2377 - cost: 654.0000
# Epoch 35/40
# 29/29 [==============================] - 1s 29ms/step - loss: 0.2291 - cost: 543.0000
# Epoch 36/40
# 29/29 [==============================] - 1s 31ms/step - loss: 0.2210 - cost: 519.0000
# Epoch 37/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2143 - cost: 535.0000
# Epoch 38/40
# 29/29 [==============================] - 1s 30ms/step - loss: 0.2064 - cost: 511.0000
# Epoch 39/40
# 29/29 [==============================] - 1s 28ms/step - loss: 0.1992 - cost: 463.0000
# Epoch 40/40
# 29/29 [==============================] - 1s 28ms/step - loss: 0.1921 - cost: 469.0000
# Epoch 1/30
# 36/36 [==============================] - 1s 28ms/step - loss: 0.7717 - cost: 1395.0000
# Epoch 2/30
# 36/36 [==============================] - 1s 27ms/step - loss: 0.5702 - cost: 1703.0000
# Epoch 3/30
# 36/36 [==============================] - 1s 28ms/step - loss: 0.5126 - cost: 1768.0000
# Epoch 4/30
# 36/36 [==============================] - 1s 27ms/step - loss: 0.4830 - cost: 1762.0000
# Epoch 5/30
# 36/36 [==============================] - 1s 29ms/step - loss: 0.4633 - cost: 1755.0000
# Epoch 6/30
# 36/36 [==============================] - 1s 32ms/step - loss: 0.4470 - cost: 1712.0000
# Epoch 7/30
# 36/36 [==============================] - 1s 29ms/step - loss: 0.4341 - cost: 1659.0000
# Epoch 8/30
# 36/36 [==============================] - 1s 28ms/step - loss: 0.4228 - cost: 1618.0000
# Epoch 9/30
# 36/36 [==============================] - 1s 30ms/step - loss: 0.4112 - cost: 1581.0000
# Epoch 10/30
# 36/36 [==============================] - 1s 33ms/step - loss: 0.4017 - cost: 1499.0000
# Epoch 11/30
# 36/36 [==============================] - 1s 31ms/step - loss: 0.3908 - cost: 1484.0000
# Epoch 12/30
# 36/36 [==============================] - 1s 29ms/step - loss: 0.3812 - cost: 1395.0000
# Epoch 13/30
# 36/36 [==============================] - 1s 28ms/step - loss: 0.3722 - cost: 1442.0000
# Epoch 14/30
# 36/36 [==============================] - 1s 32ms/step - loss: 0.3627 - cost: 1309.0000
# Epoch 15/30
# 36/36 [==============================] - 1s 30ms/step - loss: 0.3524 - cost: 1338.0000
# Epoch 16/30
# 36/36 [==============================] - 1s 30ms/step - loss: 0.3440 - cost: 1158.0000
# Epoch 17/30
# 36/36 [==============================] - 1s 29ms/step - loss: 0.3339 - cost: 1161.0000
# Epoch 18/30
# 36/36 [==============================] - 1s 31ms/step - loss: 0.3252 - cost: 1130.0000
# Epoch 19/30
# 36/36 [==============================] - 1s 30ms/step - loss: 0.3166 - cost: 1075.0000
# Epoch 20/30
# 36/36 [==============================] - 1s 33ms/step - loss: 0.3082 - cost: 1039.0000
# Epoch 21/30
# 36/36 [==============================] - 1s 28ms/step - loss: 0.3002 - cost: 1019.0000
# Epoch 22/30
# 36/36 [==============================] - 1s 29ms/step - loss: 0.2907 - cost: 964.0000
# Epoch 23/30
# 36/36 [==============================] - 1s 28ms/step - loss: 0.2815 - cost: 964.0000
# Epoch 24/30
# 36/36 [==============================] - 1s 29ms/step - loss: 0.2746 - cost: 865.0000
# Epoch 25/30
# 36/36 [==============================] - 1s 29ms/step - loss: 0.2664 - cost: 866.0000
# Epoch 26/30
# 36/36 [==============================] - 1s 35ms/step - loss: 0.2559 - cost: 770.0000
# Epoch 27/30
# 36/36 [==============================] - 1s 37ms/step - loss: 0.2477 - cost: 820.0000
# Epoch 28/30
# 36/36 [==============================] - 1s 31ms/step - loss: 0.2390 - cost: 728.0000
# Epoch 29/30
# 36/36 [==============================] - 1s 32ms/step - loss: 0.2317 - cost: 720.0000
# Epoch 30/30
# 36/36 [==============================] - 1s 33ms/step - loss: 0.2236 - cost: 639.0000
# -316.0
# {'class_weight': {0: 1, 1: 1}, 'epochs': 30, 'hidden_dim': [32, 10]}

# %%
nn = NeuralNetwork(cost_matrix, epochs=30, hidden_dim=[32, 10], class_weight={0: 1, 1: 1})

history = nn.fit(X_train, y_train)
# Out:
# Epoch 1/30
# 36/36 [==============================] - 1s 30ms/step - loss: 1.0558 - cost: 1001.0000
# Epoch 2/30
# 36/36 [==============================] - 1s 32ms/step - loss: 0.6802 - cost: 1326.0000
# Epoch 3/30
# 36/36 [==============================] - 1s 34ms/step - loss: 0.5774 - cost: 1719.0000
# Epoch 4/30
# 36/36 [==============================] - 1s 32ms/step - loss: 0.5231 - cost: 1782.0000
# Epoch 5/30
# 36/36 [==============================] - 1s 32ms/step - loss: 0.4894 - cost: 1793.0000
# Epoch 6/30
# 36/36 [==============================] - 1s 32ms/step - loss: 0.4687 - cost: 1755.0000
# Epoch 7/30
# 36/36 [==============================] - 1s 32ms/step - loss: 0.4525 - cost: 1660.0000
# Epoch 8/30
# 36/36 [==============================] - 1s 33ms/step - loss: 0.4387 - cost: 1628.0000
# Epoch 9/30
# 36/36 [==============================] - 1s 32ms/step - loss: 0.4269 - cost: 1589.0000
# Epoch 10/30
# 36/36 [==============================] - 1s 31ms/step - loss: 0.4184 - cost: 1558.0000
# Epoch 11/30
# 36/36 [==============================] - 1s 31ms/step - loss: 0.4083 - cost: 1549.0000
# Epoch 12/30
# 36/36 [==============================] - 1s 32ms/step - loss: 0.4003 - cost: 1504.0000
# Epoch 13/30
# 36/36 [==============================] - 1s 31ms/step - loss: 0.3920 - cost: 1488.0000
# Epoch 14/30
# 36/36 [==============================] - 1s 30ms/step - loss: 0.3830 - cost: 1346.0000
# Epoch 15/30
# 36/36 [==============================] - 1s 31ms/step - loss: 0.3742 - cost: 1350.0000
# Epoch 16/30
# 36/36 [==============================] - 1s 33ms/step - loss: 0.3662 - cost: 1247.0000
# Epoch 17/30
# 36/36 [==============================] - 1s 33ms/step - loss: 0.3576 - cost: 1274.0000
# Epoch 18/30
# 36/36 [==============================] - 1s 32ms/step - loss: 0.3497 - cost: 1216.0000
# Epoch 19/30
# 36/36 [==============================] - 1s 31ms/step - loss: 0.3421 - cost: 1201.0000
# Epoch 20/30
# 36/36 [==============================] - 1s 31ms/step - loss: 0.3346 - cost: 1108.0000
# Epoch 21/30
# 36/36 [==============================] - 1s 31ms/step - loss: 0.3280 - cost: 1146.0000
# Epoch 22/30
# 36/36 [==============================] - 1s 35ms/step - loss: 0.3202 - cost: 1057.0000
# Epoch 23/30
# 36/36 [==============================] - 1s 31ms/step - loss: 0.3116 - cost: 991.0000
# Epoch 24/30
# 36/36 [==============================] - 1s 32ms/step - loss: 0.3048 - cost: 977.0000
# Epoch 25/30
# 36/36 [==============================] - 1s 34ms/step - loss: 0.2965 - cost: 999.0000
# Epoch 26/30
# 36/36 [==============================] - 1s 34ms/step - loss: 0.2887 - cost: 921.0000
# Epoch 27/30
# 36/36 [==============================] - 1s 32ms/step - loss: 0.2803 - cost: 927.0000
# Epoch 28/30
# 36/36 [==============================] - 1s 31ms/step - loss: 0.2724 - cost: 841.0000
# Epoch 29/30
# 36/36 [==============================] - 1s 32ms/step - loss: 0.2644 - cost: 800.0000
# Epoch 30/30
# 36/36 [==============================] - 1s 31ms/step - loss: 0.2572 - cost: 809.0000

# %%
print('Neural Network cost (train): {}'.format(-custom_score_tf(nn, X_train, y_train)))
print('Neural Network cost (test): {}'.format(-custom_score_tf(nn, X_test, y_test)))
# Out:
# Neural Network cost (train): 744.0
# Neural Network cost (test): 422.0

# %%
threshold = 0.5
y_pred = (nn.predict(X_test) > threshold).astype('float')
cm = confusion_matrix(y_test, y_pred)

disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp = disp.plot()
plt.show()

# %% [markdown]
# ### Bibliography
#
# [1] https://ui.adsabs.harvard.edu/abs/1987Natur.329..343M/abstract
#
# [2] https://www.cdc.gov/hepatitis/hcv/pdfs/hcv_graph.pdf
#
# [3] https://www.pennmedicine.org/updates/blogs/transplant-update/2020/may/understanding-the-meld-score
#
# [4] https://www.gastrojournal.org/article/S0016-5085(03)50022-1/fulltext
#
# [5] https://orbi.uliege.be/bitstream/2268/9357/1/geurts-mlj-advance.pdf
